# %%
import json
import subprocess
import passim
from pathlib import Path
from xml.etree import ElementTree as ET
from collections import defaultdict, Counter
import pandas as pd
import networkx as nx
from IPython.display import display, Markdown

# %%
# Configuration paths
LETTERS_DIR = "/Master-Thesis/bullinger-letters/data/letters"
SOURCES_DIR = "../data/cc-tei" 

# Output files
LETTERS_JSON = "../data/passim/bullinger-letters.json"
SOURCES_JSON = "../data/passim/patristic-sources.json"
OUTPUT_DIR = "../data/passim"

# %% [markdown]
# ## Bullinger Letters

# %%
# TEI namespace
TEI_NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

def extract_text_from_letter(xml_file):
    """
    Extract text content from a Bullinger letter XML file.
    """
    try:
        tree = ET.parse(xml_file)
        root = tree.getroot()
        
        # Extract document ID
        file_id = Path(xml_file).stem
        tei_id = root.get('{http://www.w3.org/XML/1998/namespace}id', file_id)
        
        # Extract metadata
        metadata = {}
        
        title_elem = root.find('.//tei:titleStmt/tei:title', TEI_NS)
        if title_elem is not None and title_elem.text:
            metadata['title'] = title_elem.text.strip()
        
        date_elem = root.find('.//tei:correspAction[@type="sent"]/tei:date', TEI_NS)
        if date_elem is not None:
            metadata['date'] = date_elem.get('when', '')
        
        sender_elem = root.find('.//tei:correspAction[@type="sent"]/tei:persName', TEI_NS)
        if sender_elem is not None:
            metadata['sender'] = sender_elem.get('ref', '')
        
        recipient_elem = root.find('.//tei:correspAction[@type="received"]/tei:persName', TEI_NS)
        if recipient_elem is not None:
            metadata['recipient'] = recipient_elem.get('ref', '')
        
        # Extract text from body
        text_parts = []
        
        # Find all text in <s> (sentence) tags
        for s_elem in root.findall('.//tei:body//tei:s', TEI_NS):
            if s_elem.text:
                text_parts.append(s_elem.text.strip())
            for child in s_elem:
                if child.tail:
                    text_parts.append(child.tail.strip())
        
        full_text = ' '.join(text_parts)
        full_text = ' '.join(full_text.split())  # Clean whitespace
        
        return {
            'id': tei_id,
            'text': full_text,
            'series': 'bullinger_letters',
            'metadata': metadata
        }
    
    except Exception as e:
        print(f"Error processing {xml_file}: {e}")
        return None

def extract_letters(input_dir, output_file):
    """
    Process all XML files in the letters directory.
    """
    documents = []
    input_path = Path(input_dir)
    xml_files = list(input_path.glob('**/*.xml'))
    
    print(f"Found {len(xml_files)} XML files")
    
    for i, xml_file in enumerate(xml_files, 1):
        if i % 100 == 0:
            print(f"  Processing: {i}/{len(xml_files)}...")
        
        doc = extract_text_from_letter(xml_file)
        if doc and doc['text']:
            documents.append(doc)
    
    # Create output directory
    output_path = Path(output_file)
    output_path.parent.mkdir(parents=True, exist_ok=True)
    
    # Write to JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        for doc in documents:
            json.dump(doc, f, ensure_ascii=False)
            f.write('\n')
    
    # Statistics
    total_chars = sum(len(doc['text']) for doc in documents)
    avg_length = total_chars / len(documents) if documents else 0
    
    print(f"\n✓ Successfully extracted {len(documents)} letters")
    print(f"  Total characters: {total_chars:,}")
    print(f"  Average letter length: {avg_length:.0f} characters")
    print(f"  Saved to: {output_file}")
    
    return documents

# Extract letters
print("Extracting Bullinger letters.")
letters = extract_letters(LETTERS_DIR, LETTERS_JSON)

# Show sample
if letters:
    print("\nSample letter:")
    sample = letters[0]
    print(f"  ID: {sample['id']}")
    print(f"  Text preview: {sample['text'][:200]}...")
    print(f"  Metadata: {sample['metadata']}")
# Out:
# Extracting Bullinger letters.
# Found 13114 XML files
#   Processing: 100/13114...
#   Processing: 200/13114...
#   Processing: 300/13114...
#   Processing: 400/13114...
#   Processing: 500/13114...
#   Processing: 600/13114...
#   Processing: 700/13114...
#   Processing: 800/13114...
#   Processing: 900/13114...
#   Processing: 1000/13114...
#   Processing: 1100/13114...
#   Processing: 1200/13114...
#   Processing: 1300/13114...
#   Processing: 1400/13114...
#   Processing: 1500/13114...
#   Processing: 1600/13114...
#   Processing: 1700/13114...
#   Processing: 1800/13114...
#   Processing: 1900/13114...
#   Processing: 2000/13114...
#   Processing: 2100/13114...
#   Processing: 2200/13114...
#   Processing: 2300/13114...
#   Processing: 2400/13114...
#   Processing: 2500/13114...
#   Processing: 2600/13114...
#   Processing: 2700/13114...
#   Processing: 2800/13114...
#   Processing: 2900/13114...
#   Processing: 3000/13114...
#   Processing: 3100/13114...
#   Processing: 3200/13114...
#   Processing: 3300/13114...
#   Processing: 3400/13114...
#   Processing: 3500/13114...
#   Processing: 3600/13114...
#   Processing: 3700/13114...
#   Processing: 3800/13114...
#   Processing: 3900/13114...
#   Processing: 4000/13114...
#   Processing: 4100/13114...
#   Processing: 4200/13114...
#   Processing: 4300/13114...
#   Processing: 4400/13114...
#   Processing: 4500/13114...
#   Processing: 4600/13114...
#   Processing: 4700/13114...
#   Processing: 4800/13114...
#   Processing: 4900/13114...
#   Processing: 5000/13114...
#   Processing: 5100/13114...
#   Processing: 5200/13114...
#   Processing: 5300/13114...
#   Processing: 5400/13114...
#   Processing: 5500/13114...
#   Processing: 5600/13114...
#   Processing: 5700/13114...
#   Processing: 5800/13114...
#   Processing: 5900/13114...
#   Processing: 6000/13114...
#   Processing: 6100/13114...
#   Processing: 6200/13114...
#   Processing: 6300/13114...
#   Processing: 6400/13114...
#   Processing: 6500/13114...
#   Processing: 6600/13114...
#   Processing: 6700/13114...
#   Processing: 6800/13114...
#   Processing: 6900/13114...
#   Processing: 7000/13114...
#   Processing: 7100/13114...
#   Processing: 7200/13114...
#   Processing: 7300/13114...
#   Processing: 7400/13114...
#   Processing: 7500/13114...
#   Processing: 7600/13114...
#   Processing: 7700/13114...
#   Processing: 7800/13114...
#   Processing: 7900/13114...
#   Processing: 8000/13114...
#   Processing: 8100/13114...
#   Processing: 8200/13114...
#   Processing: 8300/13114...
#   Processing: 8400/13114...
#   Processing: 8500/13114...
#   Processing: 8600/13114...
#   Processing: 8700/13114...
#   Processing: 8800/13114...
#   Processing: 8900/13114...
#   Processing: 9000/13114...
#   Processing: 9100/13114...
#   Processing: 9200/13114...
#   Processing: 9300/13114...
#   Processing: 9400/13114...
#   Processing: 9500/13114...
#   Processing: 9600/13114...
#   Processing: 9700/13114...
#   Processing: 9800/13114...
#   Processing: 9900/13114...
#   Processing: 10000/13114...
#   Processing: 10100/13114...
#   Processing: 10200/13114...
#   Processing: 10300/13114...
#   Processing: 10400/13114...
#   Processing: 10500/13114...
#   Processing: 10600/13114...
#   Processing: 10700/13114...
#   Processing: 10800/13114...
#   Processing: 10900/13114...
#   Processing: 11000/13114...
#   Processing: 11100/13114...
#   Processing: 11200/13114...
#   Processing: 11300/13114...
#   Processing: 11400/13114...
#   Processing: 11500/13114...
#   Processing: 11600/13114...
#   Processing: 11700/13114...
#   Processing: 11800/13114...
#   Processing: 11900/13114...
#   Processing: 12000/13114...
#   Processing: 12100/13114...
#   Processing: 12200/13114...
#   Processing: 12300/13114...
#   Processing: 12400/13114...
#   Processing: 12500/13114...
#   Processing: 12600/13114...
#   Processing: 12700/13114...
#   Processing: 12800/13114...
#   Processing: 12900/13114...
#   Processing: 13000/13114...
#   Processing: 13100/13114...
#
# ✓ Successfully extracted 8626 letters
#   Total characters: 23,697,355
#   Average letter length: 2747 characters
#   Saved to: ../data/passim/bullinger-letters_2.json
#
# Sample letter:
#   ID: file5690
#   Text preview: Quod simul ac finis utcunque nostrae tragoediae impositus fuit, reverendissime pater, non statim ad te qualis ille fuerit scripserim, ne mireris. Quum enim in animum iam pridem induxerim meum, hoc tem...
#   Metadata: {'title': 'Girolamo Zanchi / Baden/AG an [Heinrich Bullinger], 16. April 1563', 'date': '1563-04-16', 'sender': 'p4037', 'recipient': 'p495'}

# %% [markdown]
# ## Patristic Sources (Subset from CC)

# %%
# Chunking for sources
CHUNK_SIZE = 300   # Words per chunk
CHUNK_OVERLAP = 50 # Overlapping words

# %%
def extract_text_from_source(xml_file):
    """
    Extract text content from a CC XML file.
    """
    try:
        tree = ET.parse(xml_file)
        root = tree.getroot()
        
        file_id = Path(xml_file).stem
        
        # Extract metadata
        metadata = {}
        
        title_elem = root.find('.//tei:titleStmt/tei:title', TEI_NS)
        if title_elem is not None and title_elem.text:
            metadata['title'] = title_elem.text.strip()
        
        author_elem = root.find('.//tei:titleStmt/tei:author', TEI_NS)
        if author_elem is not None:
            author_text = ''.join(author_elem.itertext()).strip()
            metadata['author'] = author_text
            viaf_ref = author_elem.get('ref', '')
            if viaf_ref:
                metadata['author_ref'] = viaf_ref
        
        series_elem = root.find('.//tei:seriesStmt/tei:title', TEI_NS)
        if series_elem is not None and series_elem.text:
            metadata['series'] = series_elem.text.strip()
        
        series_id_elem = root.find('.//tei:seriesStmt/tei:idno', TEI_NS)
        if series_id_elem is not None and series_id_elem.text:
            metadata['series_id'] = series_id_elem.text.strip()
        
        # Extract text from body
        text_parts = []
        for p_elem in root.findall('.//tei:body//tei:p', TEI_NS):
            text = ''.join(p_elem.itertext()).strip()
            if text:
                text_parts.append(text)
        
        full_text = ' '.join(text_parts)
        full_text = ' '.join(full_text.split())
        
        series_name = metadata.get('series_id', metadata.get('author', file_id))
        
        return {
            'id': file_id,
            'text': full_text,
            'series': series_name,
            'metadata': metadata
        }
    
    except Exception as e:
        print(f"Error processing {xml_file}: {e}")
        return None

def chunk_document(doc, chunk_size=300, overlap=50):
    """
    Split a document into overlapping chunks.
    """
    words = doc['text'].split()
    
    if len(words) <= chunk_size:
        return [doc]
    
    chunks = []
    chunk_id = 0
    
    for i in range(0, len(words), chunk_size - overlap):
        chunk_words = words[i:i + chunk_size]
        if not chunk_words:
            break
        
        chunk_text = ' '.join(chunk_words)
        
        chunk_doc = {
            'id': f"{doc['id']}_chunk{chunk_id}",
            'text': chunk_text,
            'series': doc['series'],
            'metadata': {
                **doc['metadata'],
                'chunk_id': chunk_id,
                'parent_id': doc['id'],
                'word_offset': i
            }
        }
        chunks.append(chunk_doc)
        chunk_id += 1
    
    return chunks

def extract_sources(input_dir, output_file, chunk_size=300, overlap=50):
    """
    Process all XML files in the sources directory.
    """
    documents = []
    input_path = Path(input_dir)
    xml_files = list(input_path.glob('**/*.xml'))
    
    print(f"Found {len(xml_files)} XML files")
    
    for xml_file in xml_files:
        doc = extract_text_from_source(xml_file)
        if doc and doc['text']:
            word_count = len(doc['text'].split())
            if word_count > chunk_size:
                chunks = chunk_document(doc, chunk_size=chunk_size, overlap=overlap)
                print(f"  {xml_file.name}: {word_count} words → {len(chunks)} chunks")
                documents.extend(chunks)
            else:
                print(f"  {xml_file.name}: {word_count} words (no chunking)")
                documents.append(doc)
    
    # Create output directory
    output_path = Path(output_file)
    output_path.parent.mkdir(parents=True, exist_ok=True)

    # Write to JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        for doc in documents:
            json.dump(doc, f, ensure_ascii=False)
            f.write('\n')
    
    # Statistics
    total_chars = sum(len(doc['text']) for doc in documents)
    avg_length = total_chars / len(documents) if documents else 0
    
    print(f"Successfully extracted {len(documents)} documents (including chunks)")
    print(f"Total characters: {total_chars:,}")
    print(f"Average document length: {avg_length:.0f} characters")
    print(f"Saved to: {output_file}")
    
    return documents

# Extract sources
print("Extracting patristic sources.")
sources = extract_sources(SOURCES_DIR, SOURCES_JSON, 
                         chunk_size=CHUNK_SIZE, overlap=CHUNK_OVERLAP)

# Show sample
if sources:
    print("\nSample source:")
    sample = sources[0]
    print(f"  ID: {sample['id']}")
    print(f"  Series: {sample['series']}")
    print(f"  Text preview: {sample['text'][:200]}...")
    print(f"  Metadata: {sample['metadata']}")
# Out:
# Extracting patristic sources.
# Found 726 XML files
#   Firmicus_Maternus-Mathesis.xml: 125089 words → 501 chunks
#   012_Julius-Firmicus-Maternus_De-errore-profanarum-religionum.xml: 14228 words → 57 chunks
#   dlt000187.xml: 125651 words → 503 chunks
#   013_Athanasius-Alexandrinus_Epistolae-ad-Luciferum.xml: 1140 words → 5 chunks
#   103_Athanasius-Alexandrinus_De-observationibus-monachorum.xml: 2325 words → 10 chunks
#   073_Athanasius-Alexandrinus_-Evagrius-Antiochensis_Vita-B.-Antonii-abbatis.xml: 16901 words → 68 chunks
#   062_Athanasius-Alexandrinus_Epistola-ad-Luciferum.xml: 3796 words → 16 chunks
#   103_Athanasius-Alexandrinus_Exhortatio-ad-sponsam-Christi.xml: 5448 words → 22 chunks
#   043_Augustinus-Hipponensis_Contra-Cresconium-grammaticum-Donatistam.xml: 58644 words → 235 chunks
#   042_Augustinus-Hipponensis_De-utilitate-credendi.xml: 11155 words → 45 chunks
#   040_Augustinus-Hipponensis_Sermo-I-de-symbolo.xml: 3991 words → 16 chunks
#   032_Augustinus-Hipponensis_De-ordine.xml: 17673 words → 71 chunks
#   032_Augustinus-Hipponensis_Principia-dialecticae.xml: 5725 words → 23 chunks
#   044_Augustinus-Hipponensis_Epistola-ad-Valerium.xml: 427 words → 2 chunks
#   044_Augustinus-Hipponensis_Contra-Julianum.xml: 96741 words → 387 chunks
#   stoa0040.stoa042.opp-lat1.xml: 14741 words → 59 chunks
#   040_Augustinus-Hipponensis_De-utilitate-jejunii.xml: 3960 words → 16 chunks
#   stoa0040.stoa057.opp-lat1.xml: 57124 words → 229 chunks
#   044_Augustinus-Hipponensis_De-correptione-et-gratia.xml: 13154 words → 53 chunks
#   stoa0040.stoa050.opp-lat1.xml: 17638 words → 71 chunks
#   042_Augustinus-Hipponensis_Contra-Priscillianistas-et-Origenistas.xml: 3658 words → 15 chunks
#   034_Augustinus-Hipponensis_De-sequentibus-libris.xml: 99 words (no chunking)
#   034_Augustinus-Hipponensis_De-subsequenti-opere.xml: 183 words (no chunking)
#   stoa0040.stoa033.opp-lat1.xml: 46197 words → 185 chunks
#   039_Augustinus-Hipponensis_Sermones-dubii.xml: 34531 words → 139 chunks
#   stoa0040.stoa034.opp-lat1.xml: 10818 words → 44 chunks
#   dlt000028.xml: 4259 words → 18 chunks
#   043_Augustinus-Hipponensis_Notitia-ex-libro-II-Rectractationum.xml: 110 words (no chunking)
#   stoa0040.stoa029a.opp-lat1.xml: 20336 words → 82 chunks
#   044_Augustinus-Hipponensis_Epistola-CCVII.xml: 269 words (no chunking)
#   stoa0040.stoa014a.opp-lat1.xml: 15376 words → 62 chunks
#   stoa0040.stoa074.opp-lat1.xml: 161632 words → 647 chunks
#   stoa0040.stoa021.opp-lat1.xml: 53539 words → 215 chunks
#   040_Augustinus-Hipponensis_De-fide-spe-et-charitate.xml: 22716 words → 91 chunks
#   034_Augustinus-Hipponensis_De-consensu-Evangelistarum.xml: 78428 words → 314 chunks
#   stoa0040.stoa011.opp-lat4.xml: 228528 words → 915 chunks
#   040_Augustinus-Hipponensis_De-fide-et-operibus.xml: 13287 words → 54 chunks
#   044_Augustinus-Hipponensis_De-nuptiis-et-concupiscentia.xml: 24732 words → 99 chunks
#   034_Augustinus-Hipponensis_Annotationes-in-Job.xml: 27482 words → 110 chunks
#   123_Augustinus-Hipponensis_Quo-genere-cultus-SS.-Martyres-venerandi-sunt.xml: 591 words → 3 chunks
#   032_Augustinus-Hipponensis_Soliloquia.xml: 15245 words → 61 chunks
#   stoa0040.stoa056.opp-lat1.xml: 24903 words → 100 chunks
#   035_Augustinus-Hipponensis_Expositio-Epistolae-ad-Galatas.xml: 18356 words → 74 chunks
#   044_Augustinus-Hipponensis_De-natura-et-gratia.xml: 18061 words → 73 chunks
#   040_Augustinus-Hipponensis_De-catechizandis-rudibus.xml: 15211 words → 61 chunks
#   stoa0040.stoa080a.opp-lat1.xml: 137806 words → 552 chunks
#   040_Augustinus-Hipponensis_De-mendacio.xml: 12572 words → 51 chunks
#   stoa0040.stoa016.opp-lat1.xml: 30578 words → 123 chunks
#   stoa0040.stoa044.opp-lat1.xml: 24511 words → 99 chunks
#   033_Augustinus-Hipponensis_Epistolae.xml: 415220 words → 1661 chunks
#   032_Augustinus-Hipponensis_De-libero-arbitrio.xml: 36895 words → 148 chunks
#   stoa0040.stoa027.opp-lat1.xml: 69538 words → 279 chunks
#   stoa0040.stoa072.opp-lat1.xml: 118 words (no chunking)
#   stoa0040.stoa066c.opp-lat1.xml: 4419 words → 18 chunks
#   stoa0040.stoa020.opp-lat1.xml: 28948 words → 116 chunks
#   032_Augustinus-Hipponensis_De-magistro.xml: 11646 words → 47 chunks
#   042_Augustinus-Hipponensis_Contra-Secundinum-Manichaeum.xml: 10423 words → 42 chunks
#   stoa0040.stoa011.opp-lat3.xml: 267743 words → 1071 chunks
#   043_Augustinus-Hipponensis_Breviculus-collationis-cum-Donatistis.xml: 14029 words → 57 chunks
#   034_Augustinus-Hipponensis_De-Genesi-ad-litteram.xml: 98043 words → 393 chunks
#   042_Augustinus-Hipponensis_De-duabus-animabus.xml: 7055 words → 29 chunks
#   040_Augustinus-Hipponensis_-Auctor-incertus_Ad-fratres-in-eremo-commorantes.xml: 65949 words → 264 chunks
#   036_Augustinus-Hipponensis_Enarrationes-in-Psalmos-1.xml: 419320 words → 1678 chunks
#   stoa0040.stoa035.opp-lat1.xml: 15212 words → 61 chunks
#   stoa0040.stoa060.opp-lat1.xml: 23246 words → 93 chunks
#   stoa0040.stoa015b.opp-lat1.xml: 1590 words → 7 chunks
#   stoa0040.stoa011.opp-lat2.xml: 297820 words → 1192 chunks
#   042_Augustinus-Hipponensis_Contra-Fortunatum-Manichaeum.xml: 7145 words → 29 chunks
#   stoa0040.stoa070a.opp-lat1.xml: 8071 words → 33 chunks
#   stoa0040.stoa032.opp-lat1.xml: 12843 words → 52 chunks
#   040_Augustinus-Hipponensis_-Auctores-varii_Liber-sententiarum.xml: 3325 words → 14 chunks
#   stoa0040.stoa003.opp-lat3.xml: 397509 words → 1591 chunks
#   042_Augustinus-Hipponensis_De-Trinitate.xml: 122322 words → 490 chunks
#   047_Augustinus-Hipponensis_De-oratione.xml: 6128 words → 25 chunks
#   043_Augustinus-Hipponensis_Epistola-ad-Catholicos-sive-De-unitate-ecclesiae.xml: 23478 words → 94 chunks
#   032_Augustinus-Hipponensis_Contra-Academicos.xml: 21330 words → 86 chunks
#   101_Augustinus-Hipponensis_Additamentum.xml: 342 words → 2 chunks
#   044_Augustinus-Hipponensis_Notitia.xml: 536 words → 3 chunks
#   042_Augustinus-Hipponensis_Contra-Adimantum.xml: 18407 words → 74 chunks
#   043_Augustinus-Hipponensis_De-gestis-cum-Emerito.xml: 3580 words → 15 chunks
#   040_Augustinus-Hipponensis_De-opere-monachorum.xml: 13596 words → 55 chunks
#   042_Augustinus-Hipponensis_Contra-adversarium-legis-et-prophetarum.xml: 26457 words → 106 chunks
#   040_Augustinus-Hipponensis_De-bono-conjugali.xml: 9422 words → 38 chunks
#   stoa0040.stoa080.opp-lat1.xml: 99541 words → 399 chunks
#   Augustinus-Hipponensis_De-dialectica.xml: 2663 words → 11 chunks
#   042_Augustinus-Hipponensis_Adversus-V-haereses.xml: 9202 words → 37 chunks
#   039_Augustinus-Hipponensis_Fragmenta-sermonum.xml: 6427 words → 26 chunks
#   044_Augustinus-Hipponensis_De-anima-et-ejus-origine.xml: 31283 words → 126 chunks
#   034_Augustinus-Hipponensis_Speculum-de-Scriptura-sacra.xml: 61904 words → 248 chunks
#   044_Augustinus-Hipponensis_De-gestis-Pelagii.xml: 16262 words → 66 chunks
#   022_Augustinus-Hipponensis_De-magnificentiis-S.-Hieronymi.xml: 3241 words → 13 chunks
#   stoa0040.stoa056b.opp-lat1.xml: 9671 words → 39 chunks
#   040_Augustinus-Hipponensis_Sermo-IV-de-symbolo.xml: 4587 words → 19 chunks
#   stoa0040.stoa033a.opp-lat1.xml: 74277 words → 298 chunks
#   044_Augustinus-Hipponensis_De-spiritu-et-littera.xml: 19123 words → 77 chunks
#   042_Augustinus-Hipponensis_Contra-Faustum-Manichaeum.xml: 130215 words → 521 chunks
#   Augustinus_Hipponensis_Epistolarum-selectio.xml: 46274 words → 186 chunks
#   042_Augustinus-Hipponensis_De-altercatione-Ecclesiae-et-Synagogae.xml: 4489 words → 18 chunks
#   stoa0040.stoa037a.opp-lat1.xml: 14120 words → 57 chunks
#   040_Augustinus-Hipponensis_De-diversis-quaestionibus.xml: 36348 words → 146 chunks
#   044_Augustinus-Hipponensis_Contra-duas-epistolas-Pelagianorum.xml: 36306 words → 146 chunks
#   040_Augustinus-Hipponensis_De-fide-et-symbolo.xml: 5999 words → 24 chunks
#   040_Augustinus-Hipponensis_Contra-mendacium.xml: 12621 words → 51 chunks
#   035_Augustinus-Hipponensis_Quaestiones-XVII-in-Matthaeum.xml: 4291 words → 18 chunks
#   032_Augustinus-Hipponensis_De-moribus-Ecclesiae.xml: 27227 words → 109 chunks
#   034_Augustinus-Hipponensis_Liber-imperfectus-de-Genesi-ad-litteram.xml: 10592 words → 43 chunks
#   042_Augustinus-Hipponensis_Contra-epistolam-Manichaei.xml: 13453 words → 54 chunks
#   035_Augustinus-Hipponensis_In-Epistolam-Joannis-ad-Parthos-tractatus-X.xml: 38252 words → 154 chunks
#   047_Augustinus-Hipponensis_De-quatuor-virtutibus-charitatis.xml: 2589 words → 11 chunks
#   040_Augustinus-Hipponensis_De-conjugiis-adulterinis.xml: 14763 words → 60 chunks
#   035_Augustinus-Hipponensis_Quaestiones-Evangeliorum.xml: 16960 words → 68 chunks
#   stoa0040.stoa057a.opp-lat1.xml: 16543 words → 67 chunks
#   044_Augustinus-Hipponensis_De-peccatorum-meritis-et-remissione.xml: 36957 words → 148 chunks
#   032_Augustinus-Hipponensis_Regula.xml: 2256 words → 10 chunks
#   040_Augustinus-Hipponensis_De-excidio-urbis.xml: 2949 words → 12 chunks
#   034_Augustinus-Hipponensis_Quaestiones-in-Heptateuchum.xml: 119304 words → 478 chunks
#   032_Augustinus-Hipponensis_Retractationes.xml: 29767 words → 120 chunks
#   stoa0040.stoa056c.opp-lat1.xml: 12857 words → 52 chunks
#   038_Augustinus-Hipponensis_Sermones-de-Sanctis.xml: 98440 words → 394 chunks
#   040_Augustinus-Hipponensis_De-patientia.xml: 5837 words → 24 chunks
#   036_Augustinus-Hipponensis_De-Psalmorum-auctore.xml: 287 words (no chunking)
#   stoa0040.stoa035a.opp-lat1.xml: 12912 words → 52 chunks
#   038_Augustinus-Hipponensis_Sermones-de-tempore.xml: 103268 words → 414 chunks
#   043_Augustinus-Hipponensis_Contra-Gaudentium.xml: 18715 words → 75 chunks
#   stoa0040.stoa029.opp-lat1.xml: 20411 words → 82 chunks
#   040_Augustinus-Hipponensis_De-divinatione-daemonum.xml: 3717 words → 15 chunks
#   040_Augustinus-Hipponensis_De-diversis-quaestionibus-ad-Simplicianum.xml: 18243 words → 73 chunks
#   040_Augustinus-Hipponensis_De-bono-viduitatis.xml: 8064 words → 33 chunks
#   stoa0040.stoa031a.opp-lat1.xml: 16336 words → 66 chunks
#   040_Augustinus-Hipponensis_Sermo-III-de-symbolo.xml: 4532 words → 19 chunks
#   040_Augustinus-Hipponensis_De-cura-pro-mortuis-gerenda.xml: 7102 words → 29 chunks
#   043_Augustinus-Hipponensis_De-unico-baptismo-contra-Petilianum.xml: 7023 words → 29 chunks
#   044_Augustinus-Hipponensis_Epistolae-ad-Valentinum.xml: 2524 words → 11 chunks
#   040_Augustinus-Hipponensis_De-quaestionibus-Dulcitii.xml: 8804 words → 36 chunks
#   stoa0040.stoa024b.opp-lat1.xml: 10291 words → 42 chunks
#   034_Augustinus-Hipponensis_De-doctrina-Christiana.xml: 41634 words → 167 chunks
#   042_Augustinus-Hipponensis_Contra-Judaeos-paganos-et-Arianos.xml: 7818 words → 32 chunks
#   stoa0040.stoa056a.opp-lat1.xml: 37585 words → 151 chunks
#   032_Augustinus-Hipponensis_De-musica.xml: 45210 words → 181 chunks
#   034_Augustinus-Hipponensis_De-sermone-Domini-in-monte.xml: 34936 words → 140 chunks
#   043_Augustinus-Hipponensis_De-baptismo-contra-Donatistas.xml: 55198 words → 221 chunks
#   040_Augustinus-Hipponensis_De-cantico-novo.xml: 3542 words → 15 chunks
#   032_Augustinus-Hipponensis_De-quantitate-animae.xml: 19322 words → 78 chunks
#   042_Augustinus-Hipponensis_Adversus-Judaeos.xml: 5136 words → 21 chunks
#   stoa0040.stoa042a.opp-lat1.xml: 150416 words → 602 chunks
#   044_Augustinus-Hipponensis_De-perfectione-justitiae-hominis.xml: 10871 words → 44 chunks
#   044_Augustinus-Hipponensis_De-gratia-et-libero-arbitrio.xml: 13796 words → 56 chunks
#   043_Augustinus-Hipponensis_Notitia-ex-libro-II-Retractationum.xml: 155 words (no chunking)
#   047_Augustinus-Hipponensis_Sermo-in-circumcisione-Domini.xml: 1440 words → 6 chunks
#   stoa0040.stoa021a.opp-lat1.xml: 19173 words → 77 chunks
#   035_Augustinus-Hipponensis_Expositio-inchoata-Epistolae-ad-Romanos.xml: 7518 words → 31 chunks
#   044_Augustinus-Hipponensis_De-praedestinatione-sanctorum.xml: 13830 words → 56 chunks
#   046_Augustinus-Hipponensis_Sermones-inediti.xml: 50205 words → 201 chunks
#   032_Augustinus-Hipponensis_De-beata-vita.xml: 7325 words → 30 chunks
#   stoa0040.stoa019.opp-lat1.xml: 80721 words → 323 chunks
#   stoa0040.stoa037c.opp-lat1.xml: 13838 words → 56 chunks
#   042_Augustinus-Hipponensis_Collatio-cum-Maximino-episcopo-Arianorum.xml: 14454 words → 58 chunks
#   031_Augustinus-Hipponensis_Confessiones.xml: 82245 words → 329 chunks
#   044_Augustinus-Hipponensis_De-gratia-Christi-et-de-peccato-originali.xml: 20629 words → 83 chunks
#   043_Augustinus-Hipponensis_Psalmus-contra-partem-Donati.xml: 1948 words → 8 chunks
#   035_Augustinus-Hipponensis_Expositio-propositionum-ex-Epistola-ad-Romanos.xml: 10069 words → 41 chunks
#   stoa0040.stoa038a.opp-lat1.xml: 6923 words → 28 chunks
#   038_Augustinus-Hipponensis_Sermones-de-Scripturis.xml: 409806 words → 1640 chunks
#   stoa0040.stoa054.opp-lat1.xml: 25549 words → 103 chunks
#   stoa0040.stoa001.opp-lat1.xml: 143718 words → 575 chunks
#   stoa0040.stoa053.opp-lat1.xml: 11803 words → 48 chunks
#   stoa0040.stoa006.opp-lat1.xml: 10692 words → 43 chunks
#   042_Augustinus-Hipponensis_De-haeresibus.xml: 9910 words → 40 chunks
#   046_Augustinus-Hipponensis_Sermones-1.xml: 21334 words → 86 chunks
#   042_Augustinus-Hipponensis_Contra-Maximinum-episcopum-Arianorum.xml: 33212 words → 133 chunks
#   stoa0040.stoa046.opp-lat1.xml: 13620 words → 55 chunks
#   stoa0040.stoa041.opp-lat1.xml: 19992 words → 80 chunks
#   043_Augustinus-Hipponensis_Post-collationem-ad-Donatistas.xml: 15284 words → 62 chunks
#   stoa0040.stoa054.opp-lat2.xml: 5452 words → 22 chunks
#   042_Augustinus-Hipponensis_De-actis-cum-Felice-Manichaeo.xml: 13586 words → 55 chunks
#   stoa0040.stoa077.opp-lat1.xml: 72971 words → 292 chunks
#   043_Augustinus-Hipponensis_Contra-epistolam-Parmeniani.xml: 29002 words → 117 chunks
#   stoa0040.stoa070.opp-lat1.xml: 38453 words → 154 chunks
#   stoa0040.stoa025.opp-lat1.xml: 23665 words → 95 chunks
#   034_Augustinus-Hipponensis_De-vera-religione.xml: 20128 words → 81 chunks
#   040_Augustinus-Hipponensis_De-agone-Christiano.xml: 8077 words → 33 chunks
#   041_Augustinus-Hipponensis_De-civitate-Dei.xml: 294367 words → 1178 chunks
#   006_Augustinus-Hipponensis_Dictum-Rheticii-de-baptismo.xml: 87 words (no chunking)
#   stoa0040.stoa062.opp-lat1.xml: 28729 words → 115 chunks
#   stoa0040.stoa037.opp-lat1.xml: 145650 words → 583 chunks
#   047_Augustinus-Hipponensis_Homilia-in-Dominica-II-Adventus.xml: 954 words → 4 chunks
#   047_Augustinus-Hipponensis_Sermones-2.xml: 3428 words → 14 chunks
#   042_Augustinus-Hipponensis_Contra-Sermonem-Arianorum.xml: 11425 words → 46 chunks
#   034_Augustinus-Hipponensis_Locutiones-in-Heptateuchum.xml: 24876 words → 100 chunks
#   stoa0040.stoa077c.opp-lat1.xml: 3491 words → 14 chunks
#   stoa0040.stoa040.opp-lat1.xml: 10176 words → 41 chunks
#   043_Augustinus-Hipponensis_Sermo-ad-plebem-ecclesiae-Caesareensis.xml: 3052 words → 13 chunks
#   040_Augustinus-Hipponensis_Sermo-II-de-symbolo.xml: 8665 words → 35 chunks
#   045_Augustinus-Hipponensis_De-dono-perseverantiae.xml: 17629 words → 71 chunks
#   stoa0040.stoa077d.opp-lat1.xml: 1668 words → 7 chunks
#   045_Augustinus-Hipponensis_Opus-imperfectum-contra-secundam-responsionem-Juliani.xml: 227334 words → 910 chunks
#   040_Augustinus-Hipponensis_De-fide-rerum-quae-non-videntur.xml: 3786 words → 16 chunks
#   040_Augustinus-Hipponensis_De-sancta-virginitate.xml: 13446 words → 54 chunks
#   043_Augustinus-Hipponensis_Contra-Litteras-Petiliani.xml: 59230 words → 237 chunks
#   034_Augustinus-Hipponensis_De-Genesi-contra-Manichaeos.xml: 19628 words → 79 chunks
#   035_Augustinus-Hipponensis_In-Joannis-evangelium-tractatus-CXXIV.xml: 268596 words → 1075 chunks
#   stoa0040.stoa055.opp-lat1.xml: 21454 words → 86 chunks
#   195_Augustinus-Hipponensis_Excerptum-de-Manichaeis.xml: 1528 words → 7 chunks
#   042_Augustinus-Hipponensis_De-natura-boni.xml: 8526 words → 35 chunks
#   032_Augustinus-Hipponensis_De-immortalitate-animae.xml: 5655 words → 23 chunks
#   stoa0040.stoa036.opp-lat1.xml: 20748 words → 83 chunks
#   stoa0040.stoa063.opp-lat1.xml: 9965 words → 40 chunks
#   stoa0040.stoa031.opp-lat1.xml: 14585 words → 59 chunks
#   039_Augustinus-Hipponensis_Sermones-de-diversis.xml: 61327 words → 246 chunks
#   040_Augustinus-Hipponensis_De-disciplina-Christiana.xml: 3867 words → 16 chunks
#   037_Augustinus-Hipponensis_Enarrationes-in-Psalmos-2.xml: 410978 words → 1644 chunks
#   stoa0040.stoa023.opp-lat1.xml: 41098 words → 165 chunks
#   006_Augustinus-Hipponensis_Admonitio-in-sequens-fragmentum.xml: 104 words (no chunking)
#   058_Gennadius-Massiliensis_De-scriptoribus-ecclesiasticis.xml: 7785 words → 32 chunks
#   058_Gennadius-Massiliensis_De-ecclesiasticis-dogmatibus.xml: 6620 words → 27 chunks
#   103_Gennadius-Massiliensis_Testimonia.xml: 89 words (no chunking)
#   022_Gennadius-Massiliensis_Vita-I-S.-Hieronymi.xml: 2343 words → 10 chunks
#   061_Gennadius-Massiliensis_Notitia-2.xml: 79 words (no chunking)
#   021_Gennadius-Massiliensis_De-scriptoribus-ecclesiasticis-cap.-17.xml: 190 words (no chunking)
#   058_Gennadius-Massiliensis_Notitia-1.xml: 50 words (no chunking)
#   042_Quodvultdeus_Epistolae.xml: 1600 words → 7 chunks
#   069_Sozomenus_-Socrates_-Theodoretus_-Cassiodorus-Vivariensis_Historia-tripartita.xml: 125635 words → 503 chunks
#   021_Joannes-Chrysostomus_Interpretatio-XXVI-homiliarum.xml: 59 words (no chunking)
#   003_Novatianus_De-cibis-Judaicis.xml: 2788 words → 12 chunks
#   003_Novatianus_Epistola-ad-S.-Cyprianum.xml: 1601 words → 7 chunks
#   003_Novatianus_De-trinitate.xml: 21741 words → 87 chunks
#   083_Isidorus-Hispalensis_Quaestiones-in-Veterum-Testamentum.xml: 68631 words → 275 chunks
#   083_Isidorus-Hispalensis_Chronicon.xml: 5427 words → 22 chunks
#   083_Isidorus-Hispalensis_De-ecclesiasticis-officiis.xml: 22482 words → 90 chunks
#   083_Isidorus-Hispalensis_Liber-numerorum-qui-in-sanctis-Scripturis-occurrunt.xml: 6432 words → 26 chunks
#   082_Isidorus-Hispalensis_Etymologiae.xml: 174020 words → 697 chunks
#   083_Isidorus-Hispalensis_Regula-monachorum-1.xml: 5888 words → 24 chunks
#   dlt000302.xml: 202 words (no chunking)
#   dlt000301.xml: 9142 words → 37 chunks
#   103_Isidorus-Hispalensis_Regula-monachorum-2.xml: 6075 words → 25 chunks
#   083_Isidorus-Hispalensis_Differentiae.xml: 24956 words → 100 chunks
#   083_Isidorus-Hispalensis_De-ordine-creaturarum.xml: 11877 words → 48 chunks
#   083_Isidorus-Hispalensis_Synonyma-de-lamentatione-animae-peccatricis.xml: 13208 words → 53 chunks
#   083_Isidorus-Hispalensis_De-fide-Catholica.xml: 27237 words → 109 chunks
#   dlt000306.xml: 6460 words → 26 chunks
#   083_Isidorus-Hispalensis_De-viris-illustribus.xml: 3979 words → 16 chunks
#   083_Isidorus-Hispalensis_Appendix-ad-libros-Regum.xml: 3531 words → 15 chunks
#   081_Isidorus-Hispalensis_Appendix-VII_-Ad-lectorem.xml: 296 words (no chunking)
#   083_Isidorus-Hispalensis_Epistolae.xml: 6189 words → 25 chunks
#   De_haeresibus.xml: 1238 words → 5 chunks
#   083_Isidorus-Hispalensis_De-natura-rerum.xml: 10994 words → 44 chunks
#   083_Isidorus-Hispalensis_Allegoriae-sacrae-Scripturae.xml: 6563 words → 27 chunks
#   081_Isidorus-Hispalensis_Appendix-VI_-Praefatio-Collectionis-canonum.xml: 351 words → 2 chunks
#   083_Isidorus-Hispalensis_De-ortu-et-obitu-Patrum.xml: 6985 words → 28 chunks
#   083_Isidorus-Hispalensis_Sententiae.xml: 47518 words → 191 chunks
#   083_Isidorus-Hispalensis_Historia-de-regibus.xml: 6796 words → 28 chunks
#   083_Isidorus-Hispalensis_Quaestiones-de-Veteri-et-Novo-Testamento.xml: 1540 words → 7 chunks
#   Isidorus-Hispalensis_Etymologiae.xml: 1317 words → 6 chunks
#   083_Isidorus-Hispalensis_Prooemia-in-libros-Veteris-ac-Novi-Testamenti.xml: 5020 words → 21 chunks
#   005_Arnobius-Afer_Segmentum.xml: 306 words → 2 chunks
#   stoa0034.stoa001.opp-lat1.xml: 93800 words → 376 chunks
#   005_Arnobius-Afer_Disputationes-adversus-gentes.xml: 70141 words → 281 chunks
#   064_Boetius_Commentaria-in-Topica-Ciceronis.xml: 57298 words → 230 chunks
#   064_Aristoteles_-Boetius_Interpretatio-Elenchorum-sophisticorum-Aristotelis.xml: 13566 words → 55 chunks
#   064_Boetius_De-syllogismo-categorico.xml: 27049 words → 109 chunks
#   064_Boetius_De-diffinitione.xml: 8099 words → 33 chunks
#   dlt000548.xml: 9532 words → 39 chunks
#   dlt000038.xml: 32892 words → 132 chunks
#   064_Boetius_De-syllogismo-hypothetico.xml: 22798 words → 92 chunks
#   064_Aristoteles_-Boetius_Interpretatio-Topicorum-Aristotelis.xml: 41300 words → 166 chunks
#   dlt000048.xml: 5985 words → 24 chunks
#   064_Boetius_Speculatio-de-rhetoricae-cognatione.xml: 1466 words → 6 chunks
#   064_Boetius_Confessio-fidei.xml: 1920 words → 8 chunks
#   063_Boetius_De-musica.xml: 33950 words → 136 chunks
#   064_Aristoteles_-Boetius_Interpretatio-Priorum-analyticorum-Aristotelis.xml: 33293 words → 134 chunks
#   063_Boetius_De-consolatione-philosophiae.xml: 30220 words → 121 chunks
#   064_Boetius_Dialogi-in-Porphyrium.xml: 25839 words → 104 chunks
#   064_Aristoteles_-Boetius_In-Categorias-Aristotelis.xml: 58262 words → 234 chunks
#   063_Euclides-Megarensis_-Boetius_Geometria.xml: 8337 words → 34 chunks
#   064_Boetius_De-Trinitate.xml: 2902 words → 12 chunks
#   dlt000041.xml: 9333 words → 38 chunks
#   dlt000055.xml: 14965 words → 60 chunks
#   dlt000056.xml: 12324 words → 50 chunks
#   dlt000042.xml: 58256 words → 234 chunks
#   dlt000043.xml: 21021 words → 85 chunks
#   064_Aristoteles_-Boetius_Interpretatio-Posteriorum-analyticorum-Aristotelis.xml: 22038 words → 89 chunks
#   dlt000046.xml: 13099 words → 53 chunks
#   064_Boetius_De-praedicatione-trium-personarum.xml: 536 words → 3 chunks
#   dlt000044.xml: 17541 words → 71 chunks
#   064_Boetius_De-divisione.xml: 6227 words → 25 chunks
#   dlt000045.xml: 6247 words → 25 chunks
#   063_Boetius_De-arithmetica.xml: 28664 words → 115 chunks
#   064_Aristoteles_-Boetius_In-librum-De-interpretatione-Aristotelis-Maior.xml: 107419 words → 430 chunks
#   dlt000547.xml: 15172 words → 61 chunks
#   064_Boetius_De-differentiis-topicis.xml: 17310 words → 70 chunks
#   stoa0058.stoa007.opp-lat2.xml: 43425 words → 174 chunks
#   064_Boetius_De-persona-et-naturis-duabus.xml: 5844 words → 24 chunks
#   064_Aristoteles_-Boetius_In-librum-De-interpretatione-Aristotelis-Minor.xml: 43720 words → 175 chunks
#   stoa0058.stoa007.opp-lat3.xml: 74190 words → 297 chunks
#   064_Boetius_Quomodo-substantiae-bonae-sint.xml: 1370 words → 6 chunks
#   064_Boetius_Distinctio-locorum-rhetoricorum.xml: 680 words → 3 chunks
#   stoa0058.stoa001.opp-lat3.xml: 28199 words → 113 chunks
#   064_Boetius_Commentaria-in-Porphyrium.xml: 36695 words → 147 chunks
#   063_Boetius_De-unitate-et-uno.xml: 1744 words → 7 chunks
#   064_Boetius_De-disciplina-scholarium.xml: 6603 words → 27 chunks
#   063_Boetius_Ars-geometriae-et-arithmeticae.xml: 4747 words → 19 chunks
#   066_Benedictus-Nursiae_Opuscula.xml: 702 words → 3 chunks
#   066_Benedictus-Nursiae_Regula-cum-commentariis.xml: 373252 words → 1494 chunks
#   dlt000338.xml: 39252 words → 158 chunks
#   dlt000339.xml: 71334 words → 286 chunks
#   005_Dionysius-Alexandrinus_Epistola-II.xml: 2067 words → 9 chunks
#   005_Dionysius-Alexandrinus_Epistolae.xml: 1752 words → 8 chunks
#   stoa0275.stoa007.opp-lat2.xml: 21871 words → 88 chunks
#   002_Tertullianus_De-corona-militis.xml: 5344 words → 22 chunks
#   stoa0275.stoa023.opp-lat2.xml: 7536 words → 31 chunks
#   002_Tertullianus_De-resurrectione-carnis.xml: 23802 words → 96 chunks
#   001_Tertullianus_Ad-martyres.xml: 1551 words → 7 chunks
#   002_Tertullianus_Adversus-Hermogenem.xml: 11550 words → 47 chunks
#   002_Tertullianus_De-carne-Christi.xml: 10180 words → 41 chunks
#   001_Tertullianus_Ad-uxorem.xml: 4430 words → 18 chunks
#   001_Tertullianus_De-poenitentia.xml: 5300 words → 22 chunks
#   stoa0275.stoa006.opp-lat2.xml: 121168 words → 485 chunks
#   001_Tertullianus_Ad-Scapulam.xml: 2321 words → 10 chunks
#   002_Tertullianus_De-pudicitia.xml: 14642 words → 59 chunks
#   001_Tertullianus_De-patientia.xml: 4794 words → 20 chunks
#   stoa0275.stoa030.opp-lat2.xml: 12080 words → 49 chunks
#   stoa0276.stoa003.opp-lat2.xml: 4489 words → 18 chunks
#   stoa0275.stoa025.opp-lat2.xml: 17889 words → 72 chunks
#   stoa0275.stoa028.opp-lat2.xml: 3268 words → 14 chunks
#   001_Tertullianus_De-idololatria.xml: 7395 words → 30 chunks
#   002_Tertullianus_Adversus-Praxeam.xml: 15368 words → 62 chunks
#   001_Tertullianus_De-baptismo.xml: 4550 words → 19 chunks
#   Tertullianus_Apologeticum.xml: 19968 words → 80 chunks
#   stoa0275.stoa018.opp-lat2.xml: 7641 words → 31 chunks
#   002_Tertullianus_De-praescriptionibus-adversus-haereticos.xml: 13029 words → 53 chunks
#   002_Tertullianus_Scorpiace-adversus-Gnosticos.xml: 8238 words → 33 chunks
#   002_Tertullianus_De-exhortatione-castitatis.xml: 3956 words → 16 chunks
#   001_Tertullianus_De-testimonio-animae.xml: 2326 words → 10 chunks
#   002_Tertullianus_De-fuga-in-persecutione.xml: 5739 words → 23 chunks
#   stoa0275.stoa008.opp-lat2.xml: 11293 words → 46 chunks
#   002_Tertullianus_Adversus-Valentinianos.xml: 8197 words → 33 chunks
#   001_Tertullianus_Apologeticus-adversus-gentes.xml: 23474 words → 94 chunks
#   002_Tertullianus_Adversus-Marcionem.xml: 89664 words → 359 chunks
#   001_Tertullianus_De-cultu-feminarum.xml: 5469 words → 22 chunks
#   002_Tertullianus_De-monogamia.xml: 7260 words → 30 chunks
#   001_Tertullianus_De-oratione.xml: 6668 words → 27 chunks
#   stoa0275.stoa011.opp-lat2.xml: 5584 words → 23 chunks
#   stoa0275.stoa004.opp-lat2.xml: 17414 words → 70 chunks
#   002_Tertullianus_Adversus-Judaeos.xml: 12428 words → 50 chunks
#   001_Auctor-incertus_Responsa-ex-libris-Digestorum.xml: 549 words → 3 chunks
#   stoa0275.stoa027.opp-lat2.xml: 10250 words → 41 chunks
#   stoa0275.stoa020.opp-lat2.xml: 6730 words → 27 chunks
#   002_Tertullianus_De-jejuniis.xml: 6121 words → 25 chunks
#   stoa0275.stoa002.opp-lat2.xml: 26584 words → 107 chunks
#   002_Tertullianus_De-anima.xml: 23848 words → 96 chunks
#   stoa0275.stoa010.opp-lat2.xml: 33431 words → 134 chunks
#   Tertullianus_De-Spectaculis.xml: 6364 words → 26 chunks
#   stoa0275.stoa017.opp-lat2.xml: 9548 words → 39 chunks
#   stoa0275.stoa026.opp-lat2.xml: 32392 words → 130 chunks
#   001_Tertullianus_Ad-nationes.xml: 15938 words → 64 chunks
#   002_Tertullianus_De-virginibus-velandis.xml: 5970 words → 24 chunks
#   065_Fulgentius-Ruspensis_Responsio-contra-Arianos.xml: 8387 words → 34 chunks
#   065_Fulgentius-Ruspensis_De-Trinitate.xml: 4973 words → 20 chunks
#   065_Fulgentius-Ruspensis_Libri-ad-Monimum.xml: 23332 words → 94 chunks
#   065_Fulgentius-Ruspensis_Libri-ad-Trasimundum.xml: 32058 words → 129 chunks
#   065_Fulgentius-Ruspensis_Sermones-inediti.xml: 3563 words → 15 chunks
#   065_Fulgentius-Ruspensis_De-incarnatione-filii-Dei.xml: 13047 words → 53 chunks
#   065_Fulgentius-Ruspensis_Pro-fide-Catholica.xml: 5593 words → 23 chunks
#   065_Fulgentius-Ruspensis_Contra-sermonem-Fastidiosi-Ariani.xml: 8445 words → 34 chunks
#   065_Fulgentius-Ruspensis_De-fide.xml: 14517 words → 59 chunks
#   065_Fulgentius-Ruspensis_De-veritate-praedestinationis.xml: 28295 words → 114 chunks
#   065_Fulgentius-Ruspensis_Sermones.xml: 11911 words → 48 chunks
#   065_Fulgentius-Ruspensis_Instrumenta-fidei.xml: 36993 words → 148 chunks
#   065_Fulgentius-Ruspensis_De-remissione-peccatorum.xml: 18516 words → 75 chunks
#   065_Fulgentius-Ruspensis_Epistolae.xml: 80833 words → 324 chunks
#   077_Gregorius-I_Appendix-1.xml: 5435 words → 22 chunks
# Error processing ../data/cc-tei/1165/066_Gregorius-I_Prolegomena.xml: not well-formed (invalid token): line 76, column 43
#   076_Gregorius-I_Homiliae-in-Evangelia.xml: 91572 words → 367 chunks
#   078_Gregorius-I_Liber-responsalis.xml: 59567 words → 239 chunks
#   075_Gregorius-I_Moralia.xml: 241369 words → 966 chunks
#   077_Gregorius-I_Dialogi.xml: 100170 words → 401 chunks
#   079_Gregorius-I_Expositio-in-psalmos-poenitentiales.xml: 45558 words → 183 chunks
#   078_Gregorius-I_Appendix-ad-Librum-sacramentorum.xml: 9003 words → 37 chunks
#   078_Gregorius-I_Aliae-benedictiones.xml: 8984 words → 36 chunks
#   078_Gregorius-I_Liber-antiphonarius.xml: 27227 words → 109 chunks
#   078_Gregorius-I_Benedictionale.xml: 4154 words → 17 chunks
#   078_Gregorius-I_Constitutiones-Lateranenses.xml: 3065 words → 13 chunks
#   075_Gregorius-I_Tabulae-donariorum-marmoreae.xml: 3579 words → 15 chunks
#   077_Gregorius-I_Epistolae.xml: 225587 words → 903 chunks
#   Rescriptum_beati_Gregorii_Papae_ad_Augustinum_episcopum_quem_Saxoniam_in_praedicatione_direxerat.xml: 18566 words → 75 chunks
#   076_Gregorius-I_De-mortalitate.xml: 459 words → 2 chunks
#   078_Gregorius-I_Benedictiones.xml: 1581 words → 7 chunks
#   076_Gregorius-I_Moralia-II.xml: 837 words → 4 chunks
#   078_Gregorius-I_Appendix-2.xml: 333 words → 2 chunks
#   079_Gregorius-I_Expositio-super-Cantica-canticorum.xml: 29339 words → 118 chunks
#   077_Gregorius-I_Regula-pastoralis.xml: 42063 words → 169 chunks
#   079_Gregorius-I_Commentarii-in-librum-I-Regum.xml: 185779 words → 744 chunks
#   078_Gregorius-I_Liber-sacramentorum.xml: 69187 words → 277 chunks
#   076_Gregorius-I_Homiliae-in-Ezechielem.xml: 111264 words → 446 chunks
#   079_Gregorius-I_Concordia-testimoniorum-S.-Scripturae.xml: 6755 words → 28 chunks
#   078_Gregorius-I_Hymni.xml: 602 words → 3 chunks
#   tlg2040.tlg002.perseus-grc1.xml: 4970 words → 20 chunks
#   103_Basilius-Caesareae_Admonitio-ad-filium-spiritualem.xml: 5831 words → 24 chunks
#   036_Basilius-Caesareae_-Rufinus-Aquileiensis_Prologus-in-librum-Psalmorum.xml: 689 words → 3 chunks
#   103_Basilius-Caesareae_Regula-S.-Basilii.xml: 27285 words → 110 chunks
#   tlg2040.tlg004.perseus-grc1.xml: 140861 words → 564 chunks
#   008_Marius-Victorinus_De-physicis.xml: 6090 words → 25 chunks
#   008_Marius-Victorinus_De-homoousio-recipiendo.xml: 1172 words → 5 chunks
#   008_Marius-Victorinus_De-generatione-Divini-Verbi.xml: 5599 words → 23 chunks
#   008_Marius-Victorinus_Adversus-Arium.xml: 47018 words → 189 chunks
#   008_Marius-Victorinus_In-epistolam-Pauli-ad-Galatas.xml: 20075 words → 81 chunks
#   008_Marius-Victorinus_De-verbis-Scripturae.xml: 2006 words → 9 chunks
#   008_Marius-Victorinus_Contra-duo-principia-Manichaeorum.xml: 4238 words → 17 chunks
#   008_Marius-Victorinus_In-epistolam-Pauli-ad-Ephesios.xml: 24606 words → 99 chunks
#   008_Marius-Victorinus_In-epistolam-Pauli-ad-Philippenses.xml: 15100 words → 61 chunks
#   018_Ambrosius-Mediolanensis_Sermones.xml: 4238 words → 17 chunks
#   stoa0022.stoa025.opp-lat1.xml: 20512 words → 83 chunks
#   015_Ambrosius-Mediolanensis_Expositio-in-psalmum-David-CXVIII.xml: 123834 words → 496 chunks
#   016_Ambrosius-Mediolanensis_De-Spiritu-Sancto.xml: 40224 words → 161 chunks
#   stoa0022.stoa054.opp-lat1.xml: 93439 words → 374 chunks
#   016_Ambrosius-Mediolanensis_De-mysteriis.xml: 5107 words → 21 chunks
#   014_Ambrosius-Mediolanensis_De-Elia-et-jejunio.xml: 9796 words → 40 chunks
#   stoa0022.stoa014.opp-lat1.xml: 17489 words → 70 chunks
#   stoa0022.stoa015.opp-lat1.xml: 20516 words → 83 chunks
#   016_Ambrosius-Mediolanensis_De-viduis.xml: 9123 words → 37 chunks
#   016_Ambrosius-Mediolanensis_De-obitu-Valentiniani-consolatio.xml: 7295 words → 30 chunks
#   stoa0022.stoa052.opp-lat1.xml: 182396 words → 730 chunks
#   014_Ambrosius-Mediolanensis_Hexaemeron.xml: 54858 words → 220 chunks
#   014_Ambrosius-Mediolanensis_De-Jacob-et-vita-beata.xml: 14085 words → 57 chunks
#   016_Ambrosius-Mediolanensis_De-virginitate.xml: 12594 words → 51 chunks
#   stoa0022.stoa029.opp-lat1.xml: 17134 words → 69 chunks
#   014_Ambrosius-Mediolanensis_Enarrationes-in-XII-psalmos-Davidicos.xml: 100660 words → 403 chunks
#   015_Ambrosius-Mediolanensis_Commentarius-in-Cantica-canticorum.xml: 44493 words → 178 chunks
#   stoa0022.stoa019.opp-lat1.xml: 12832 words → 52 chunks
#   014_Ambrosius-Mediolanensis_Apologia-Prophetae-David.xml: 11273 words → 46 chunks
#   014_Ambrosius-Mediolanensis_De-Abraham.xml: 28277 words → 114 chunks
#   016_Ambrosius-Mediolanensis_De-lapsu-virginis-consecratae.xml: 4630 words → 19 chunks
#   014_Ambrosius-Mediolanensis_De-Joseph-Patriarcha.xml: 10859 words → 44 chunks
#   016_Ambrosius-Mediolanensis_Epistolarum-classis-I.xml: 103348 words → 414 chunks
#   014_Ambrosius-Mediolanensis_De-fuga-saeculi.xml: 9484 words → 38 chunks
#   stoa0022.stoa038.opp-lat1.xml: 17729 words → 71 chunks
#   016_Ambrosius-Mediolanensis_Exhortatio-virginitatis.xml: 9817 words → 40 chunks
#   014_Ambrosius-Mediolanensis_De-Cain-et-Abel.xml: 16610 words → 67 chunks
#   015_Ambrosius-Mediolanensis_Anacephalaeosis-Historiae-de-excidio-Hierosolymitanae-urbis.xml: 5056 words → 21 chunks
#   stoa0022.stoa048.opp-lat1.xml: 141834 words → 568 chunks
#   014_Ambrosius-Mediolanensis_De-Isaac-et-Anima.xml: 12228 words → 49 chunks
#   015_Ambrosius-Mediolanensis_De-excidio-urbis-Hierosolymitanae.xml: 87991 words → 352 chunks
#   016_Ambrosius-Mediolanensis_De-incarnationis-Dominicae-sacramento.xml: 9680 words → 39 chunks
#   014_Ambrosius-Mediolanensis_De-paradiso.xml: 15153 words → 61 chunks
#   016_Ambrosius-Mediolanensis_De-excessu-fratris-sui-Satyrus.xml: 20230 words → 81 chunks
#   016_Ambrosius-Mediolanensis_De-institutione-virginis.xml: 9443 words → 38 chunks
#   016_Ambrosius-Mediolanensis_De-obitu-Theodosii-oratio.xml: 5484 words → 22 chunks
#   016_Ambrosius-Mediolanensis_De-officiis-ministrorum.xml: 47386 words → 190 chunks
#   stoa0022.stoa039.opp-lat1.xml: 28459 words → 114 chunks
#   stoa0022.stoa034.opp-lat1.xml: 24909 words → 100 chunks
#   016_Ambrosius-Mediolanensis_De-virginibus.xml: 13533 words → 55 chunks
#   014_Ambrosius-Mediolanensis_De-bono-mortis.xml: 10263 words → 42 chunks
#   016_Ambrosius-Mediolanensis_Epistolarum-classis-II.xml: 22261 words → 90 chunks
#   014_Ambrosius-Mediolanensis_Apologia-altera-prophetae-David.xml: 10956 words → 44 chunks
#   stoa0022.stoa021.opp-lat1.xml: 23695 words → 95 chunks
#   015_Ambrosius-Mediolanensis_Expositio-Evangelii-secundum-Lucam.xml: 115634 words → 463 chunks
#   014_Ambrosius-Mediolanensis_De-interpellatione-Job-et-David.xml: 20069 words → 81 chunks
#   stoa0022.stoa042.opp-lat1.xml: 26219 words → 105 chunks
#   016_Ambrosius-Mediolanensis_De-sacramentis.xml: 11735 words → 47 chunks
#   014_Ambrosius-Mediolanensis_Fragmentum.xml: 147 words (no chunking)
#   014_Ambrosius-Mediolanensis_De-Nabuthe-Jezraelita.xml: 8925 words → 36 chunks
#   stoa0022.stoa035.opp-lat1.xml: 17996 words → 72 chunks
#   014_Ambrosius-Mediolanensis_De-Noe-et-Arca.xml: 19398 words → 78 chunks
#   016_Ambrosius-Mediolanensis_Fragmentum-ex-Theodoreto-desumptum.xml: 1032 words → 5 chunks
#   stoa0022.stoa032.opp-lat1.xml: 30159 words → 121 chunks
#   016_Ambrosius-Mediolanensis_De-fide.xml: 59181 words → 237 chunks
#   stoa0022.stoa051.opp-lat1.xml: 190816 words → 764 chunks
#   014_Ambrosius-Mediolanensis_De-benedictionibus-patriarcharum.xml: 7277 words → 30 chunks
# Error processing ../data/cc-tei/958/016_Ambrosius-Mediolanensis_De-poenitentia.xml: not well-formed (invalid token): line 108, column 9
#   014_Ambrosius-Mediolanensis_De-Tobia.xml: 11394 words → 46 chunks
#   stoa0022.stoa044.opp-lat1.xml: 19192 words → 77 chunks
#   048_Rufinus-Aquileiensis_Confessio-fidei.xml: 415 words → 2 chunks
#   021_Rufinus-Aquileiensis_Historia-monachorum.xml: 25415 words → 102 chunks
#   103_Rufinus-Aquileiensis_Praefatio.xml: 242 words (no chunking)
#   021_Rufinus-Aquileiensis_Opera-Tyrannii-Rufini.xml: 186 words (no chunking)
#   021_Rufinus-Aquileiensis_De-benedictionibus-patriarcharum.xml: 11895 words → 48 chunks
#   stoa0244d.stoa005.opp-lat1.xml: 41038 words → 165 chunks
#   021_Rufinus-Aquileiensis_Apologia-ad-Anastasium.xml: 1002 words → 5 chunks
#   021_Rufinus-Aquileiensis_Commentarius-in-Symbolum-apostolorum.xml: 13302 words → 54 chunks
#   021_Rufinus-Aquileiensis_Historia-ecclesiastica.xml: 18821 words → 76 chunks
#   021_Rufinus-Aquileiensis_Apologia-in-Sanctum-Hieronymum.xml: 27704 words → 111 chunks
#   006_Lactantius_Divinarum-institutionum-liber-VII.xml: 16847 words → 68 chunks
#   007_Lactantius_Liber-de-opificio-Dei.xml: 10998 words → 44 chunks
#   006_Lactantius_Epitome-Divinarum-institutionum.xml: 17735 words → 71 chunks
#   006_Lactantius_Divinarum-institutionum-liber-III.xml: 18292 words → 74 chunks
#   007_Lactantius_Liber-de-ira-Dei.xml: 12104 words → 49 chunks
#   006_Lactantius_Divinarum-institutionum-liber-IV.xml: 17836 words → 72 chunks
#   stoa0171.stoa006.opp-lat1.xml: 24590 words → 99 chunks
#   006_Lactantius_Divinarum-institutionum-liber-I.xml: 17716 words → 71 chunks
#   stoa0171.stoa007.opp-lat1.xml: 23531 words → 95 chunks
#   stoa0171.stoa010.opp-lat1.xml: 3029 words → 13 chunks
#   007_Lactantius_Liber-de-mortibus-persecutorum.xml: 10785 words → 44 chunks
#   stoa0171.stoa002.opp-lat1.xml: 22855 words → 92 chunks
#   006_Lactantius_Divinarum-institutionum-liber-V.xml: 14972 words → 60 chunks
#   006_Lactantius_Divinarum-institutionum-liber-VI.xml: 18657 words → 75 chunks
#   stoa0171.stoa009.opp-lat1.xml: 264506 words → 1059 chunks
#   stoa0171.stoa008.opp-lat1.xml: 31821 words → 128 chunks
#   007_Lactantius_Fragmenta.xml: 340 words → 2 chunks
#   006_Lactantius_Divinarum-institutionum-liber-II.xml: 15875 words → 64 chunks
#   074_Theodoretus-Cyrensis_Philotheus-sive-Theophiles.xml: 41707 words → 167 chunks
#   023_Hieronymus-Stridonensis_De-situ-et-nominibus-locorum-Hebraicorum.xml: 17249 words → 69 chunks
#   Hieronymus-Stridonensis_Epistulae-selectae.xml: 43934 words → 176 chunks
#   028_Hieronymus-Stridonensis_Liber-Exodi.xml: 23120 words → 93 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Abdiam.xml: 7463 words → 30 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Hebraeos.xml: 4709 words → 19 chunks
#   stoa0162.stoa024.opp-lat1.xml: 152377 words → 610 chunks
#   024_Hieronymus-Stridonensis_Commentaria-in-Jeremiam.xml: 87928 words → 352 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Thessalonicenses-I.xml: 1439 words → 6 chunks
#   073_Hieronymus-Stridonensis_Vita-S.-Pauli.xml: 48 words (no chunking)
#   028_Hieronymus-Stridonensis_Liber-Josue.xml: 13621 words → 55 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Timotheum-I.xml: 1624 words → 7 chunks
#   023_Hieronymus-Stridonensis_Adversus-Jovinianum.xml: 45321 words → 182 chunks
#   028_Hieronymus-Stridonensis_Liber-Deuteronomii.xml: 23650 words → 95 chunks
#   029_Hieronymus-Stridonensis_Liber-Judith.xml: 6858 words → 28 chunks
#   023_Hieronymus-Stridonensis_Contra-Joannem-Hierosolymitanum.xml: 14726 words → 59 chunks
#   026_Hieronymus-Stridonensis_Commentaria-in-Job.xml: 74057 words → 297 chunks
#   028_Hieronymus-Stridonensis_Synopsis-Bibliothecae-divinae.xml: 1613 words → 7 chunks
#   023_Hieronymus-Stridonensis_Contra-Vigilantium.xml: 4534 words → 19 chunks
#   023_Hieronymus-Stridonensis_Vita-Malchi-monachi-captivi.xml: 2089 words → 9 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Malachiam.xml: 14212 words → 57 chunks
#   009_Hieronymus-Stridonensis_Vita-Sancti-Hilarii.xml: 154 words (no chunking)
#   029_Hieronymus-Stridonensis_Liber-Tobiae.xml: 5227 words → 21 chunks
#   029_Hieronymus-Stridonensis_Liber-Job-2.xml: 15161 words → 61 chunks
#   023_Hieronymus-Stridonensis_Dialogus-contra-Luciferianos.xml: 8919 words → 36 chunks
#   028_Hieronymus-Stridonensis_Liber-Job-1.xml: 2298 words → 10 chunks
#   028_Hieronymus-Stridonensis_Libri-Samuelis-et-Malachim.xml: 79144 words → 317 chunks
#   028_Hieronymus-Stridonensis_Liber-Ezrae.xml: 13182 words → 53 chunks
#   023_Hieronymus-Stridonensis_Commentarius-in-Ecclesiasten.xml: 33734 words → 135 chunks
#   029_Hieronymus-Stridonensis_Actus-apostolorum.xml: 16861 words → 68 chunks
#   023_Hieronymus-Stridonensis_Apologia-adversus-libros-Rufini.xml: 33461 words → 134 chunks
#   028_Hieronymus-Stridonensis_Liber-Proverbiorum.xml: 22 words (no chunking)
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Titum.xml: 679 words → 3 chunks
#   022_Hieronymus-Stridonensis_Epistolae.xml: 311045 words → 1245 chunks
#   023_Hieronymus-Stridonensis_De-virginitate-B.-Mariae.xml: 7617 words → 31 chunks
#   023_Hieronymus-Stridonensis_Vita-S.-Pauli-primi-eremitae.xml: 2710 words → 11 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Aggaeum.xml: 11273 words → 46 chunks
#   023_Hieronymus-Stridonensis_De-nominibus-Hebraicis.xml: 18501 words → 75 chunks
#   026_Hieronymus-Stridonensis_Commentaria-in-Epistolam-ad-Philemonem.xml: 6990 words → 28 chunks
#   029_Hieronymus-Stridonensis_Evangelium-secundum-Marcum.xml: 10868 words → 44 chunks
#   023_Hieronymus-Stridonensis_Quaestiones-Hebraicae-in-Genesim.xml: 19007 words → 77 chunks
#   028_Hieronymus-Stridonensis_Liber-Danielis.xml: 8271 words → 34 chunks
#   028_Hieronymus-Stridonensis_Liber-Numerorum.xml: 21503 words → 87 chunks
#   028_Hieronymus-Stridonensis_Praefatio-in-libros-Salomonis.xml: 270 words (no chunking)
#   026_Hieronymus-Stridonensis_Commentaria-in-Epistolam-ad-Galatas.xml: 48956 words → 196 chunks
#   023_Hieronymus-Stridonensis_De-viris-illustribus.xml: 25697 words → 103 chunks
#   028_Hieronymus-Stridonensis_Canticum-Canticorum.xml: 3 words (no chunking)
#   028_Hieronymus-Stridonensis_Libri-XII-Prophetarum.xml: 159 words (no chunking)
#   029_Hieronymus-Stridonensis_Epistola-Joannis-II.xml: 226 words (no chunking)
#   165_Hieronymus-Stridonensis_Prologus.xml: 1385 words → 6 chunks
#   024_Hieronymus-Stridonensis_Commentaria-in-Isaiam.xml: 264194 words → 1057 chunks
#   028_Hieronymus-Stridonensis_Liber-Genesis.xml: 29595 words → 119 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Philemonem.xml: 337 words → 2 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Jonam.xml: 12694 words → 51 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Amos.xml: 41862 words → 168 chunks
#   027_Hieronymus-Stridonensis_Chronicon-S.-Hieronymi.xml: 2651 words → 11 chunks
#   026_Hieronymus-Stridonensis_Commentaria-in-Epistolam-ad-Titum.xml: 16877 words → 68 chunks
#   029_Hieronymus-Stridonensis_Epistola-Petri-I.xml: 1678 words → 7 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Romanos.xml: 6716 words → 27 chunks
#   028_Hieronymus-Stridonensis_Liber-Psalmorum-1.xml: 21165 words → 85 chunks
#   028_Hieronymus-Stridonensis_Liber-Ezechielis.xml: 179 words (no chunking)
#   023_Hieronymus-Stridonensis_-Auctores-incerti_De-X-nominibus-Dei.xml: 1134 words → 5 chunks
#   030_Hieronymus-Stridonensis_De-formis-Hebraicarum-litterarum.xml: 163 words (no chunking)
#   028_Hieronymus-Stridonensis_Praefatio-in-Pentateuchum.xml: 612 words → 3 chunks
#   026_Hieronymus-Stridonensis_Commentaria-in-Matthaeum.xml: 69322 words → 278 chunks
#   023_Hieronymus-Stridonensis_Vita-S.-Hilarionis.xml: 7499 words → 30 chunks
#   028_Hieronymus-Stridonensis_Liber-Esther.xml: 6330 words → 26 chunks
#   003_Hieronymus-Stridonensis_Notitia-historica.xml: 74 words (no chunking)
#   028_Hieronymus-Stridonensis_Liber-Levitici.xml: 14961 words → 60 chunks
#   029_Hieronymus-Stridonensis_Epistola-Petri-II.xml: 1069 words → 5 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Osee.xml: 50768 words → 204 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Joelem.xml: 16394 words → 66 chunks
#   028_Hieronymus-Stridonensis_Liber-Ecclesiastes.xml: 3 words (no chunking)
#   029_Hieronymus-Stridonensis_Liber-Psalmorum-2.xml: 67092 words → 269 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Corinthios-I.xml: 6512 words → 27 chunks
#   023_Hieronymus-Stridonensis_Excerpta-de-aliquot-Palestinae-locis.xml: 2432 words → 10 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Colossenses.xml: 1488 words → 6 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Corinthios-II.xml: 4400 words → 18 chunks
#   029_Hieronymus-Stridonensis_Epistola-Judae.xml: 449 words → 2 chunks
#   029_Hieronymus-Stridonensis_Evangelium-secundum-Joannem.xml: 14680 words → 59 chunks
#   028_Hieronymus-Stridonensis_Liber-Isaiae.xml: 1362 words → 6 chunks
#   029_Hieronymus-Stridonensis_Apocalypsis-Joannis.xml: 8705 words → 35 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Danielem.xml: 32629 words → 131 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Ezechielem.xml: 191500 words → 766 chunks
#   028_Hieronymus-Stridonensis_Liber-Paralipomenon.xml: 32976 words → 132 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Philippenses.xml: 1592 words → 7 chunks
#   stoa0162.stoa004.opp-lat3.xml: 135719 words → 543 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Ephesios.xml: 2205 words → 9 chunks
#   029_Hieronymus-Stridonensis_Evangelium-secundum-Lucam.xml: 18863 words → 76 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Sophoniam.xml: 19448 words → 78 chunks
#   stoa0162.stoa004.opp-lat2.xml: 197463 words → 790 chunks
#   028_Hieronymus-Stridonensis_Liber-Jeremiae.xml: 1182 words → 5 chunks
#   029_Hieronymus-Stridonensis_Praefationes-aliae.xml: 1318 words → 6 chunks
#   023_Hieronymus-Stridonensis_Dialogus-contra-Pelagianos.xml: 35272 words → 142 chunks
#   029_Hieronymus-Stridonensis_Praefatio-in-Evangelia.xml: 682 words → 3 chunks
#   029_Hieronymus-Stridonensis_Evangelium-secundum-Matthaeum.xml: 17390 words → 70 chunks
#   stoa0162.stoa004.opp-lat1.xml: 253197 words → 1013 chunks
#   028_Hieronymus-Stridonensis_Liber-Judicum.xml: 14367 words → 58 chunks
#   029_Hieronymus-Stridonensis_Epistola-Joannis-I.xml: 1912 words → 8 chunks
#   029_Hieronymus-Stridonensis_Epistola-Joannis-III.xml: 217 words (no chunking)
#   026_Hieronymus-Stridonensis_Commentaria-in-Epistolam-ad-Ephesios.xml: 44350 words → 178 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Galatas.xml: 2193 words → 9 chunks
#   028_Hieronymus-Stridonensis_Liber-Ruth.xml: 1878 words → 8 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Michaeam.xml: 31571 words → 127 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Zachariam.xml: 51460 words → 206 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Thessalonicenses-II.xml: 771 words → 4 chunks
#   029_Hieronymus-Stridonensis_Epistola-Jacobi.xml: 1669 words → 7 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Abacuc.xml: 25293 words → 102 chunks
#   025_Hieronymus-Stridonensis_Commentaria-in-Naum.xml: 16031 words → 65 chunks
#   029_Hieronymus-Stridonensis_Epistola-Pauli-ad-Timotheum-II.xml: 1201 words → 5 chunks
#   026_Origenes_-Hieronymus-Stridonensis_Translatio-XXXIX-Homiliarum.xml: 31972 words → 128 chunks
#   023_Origenes_-Hieronymus-Stridonensis_Interpretatio-homiliarum-Origenis-in-Canticum-canticorum.xml: 9074 words → 37 chunks
#   042_Origenes_De-incarnatione-Verbi.xml: 9586 words → 39 chunks
#   024_Origenes_-Hieronymus-Stridonensis_Translatio-homiliarum-in-visiones-Isaiae.xml: 14533 words → 59 chunks
#   Origenes_De-principiis.xml: 67348 words → 270 chunks
#   025_Origenes_-Hieronymus-Stridonensis_Translatio-Homiliarum-in-Jeremiam-et-Ezechielem.xml: 76107 words → 305 chunks
#   stoa0149b.stoa006.opp-lat1.xml: 581 words → 3 chunks
#   010_Hilarius-Pictaviensis_De-Trinitate.xml: 129627 words → 519 chunks
#   stoa0149b.stoa001.opp-lat1.xml: 317601 words → 1271 chunks
#   010_Hilarius-Pictaviensis_Liber-secundus-ad-Constantium.xml: 1804 words → 8 chunks
#   stoa0149b.stoa007.opp-lat1.xml: 2670 words → 11 chunks
#   010_Hilarius-Pictaviensis_Liber-contra-Constantium.xml: 5870 words → 24 chunks
#   010_Hilarius-Pictaviensis_Liber-de-synodis-seu-fide-orientalium.xml: 16135 words → 65 chunks
#   010_Hilarius-Pictaviensis_Fragmenta-ex-opere-historico.xml: 21854 words → 88 chunks
#   010_Hilarius-Pictaviensis_Liber-contra-Arianos-vel-Auxentium.xml: 2401 words → 10 chunks
#   010_Hilarius-Pictaviensis_Sermo-de-dedicatione-ecclesiae.xml: 1440 words → 6 chunks
#   009_Hilarius-Pictaviensis_Commentarius-in-psalmos-XV-XXXI-XLI.xml: 7742 words → 31 chunks
#   stoa0149b.stoa009.opp-lat1.xml: 12675 words → 51 chunks
#   010_Hilarius-Pictaviensis_Apologetica-responsa-ad-reprehensores-libri-de-synodis.xml: 608 words → 3 chunks
#   010_Hilarius-Pictaviensis_Epistola-seu-libellus.xml: 7735 words → 31 chunks
#   stoa0149b.stoa008.opp-lat1.xml: 3171 words → 13 chunks
#   stoa0149b.stoa005.opp-lat1.xml: 3473 words → 14 chunks
#   010_Hilarius-Pictaviensis_Epistola-ad-Abram.xml: 1147 words → 5 chunks
#   stoa0149b.stoa002.opp-lat1.xml: 49203 words → 197 chunks
#   009_Hilarius-Pictaviensis_Commentarius-in-Matthaeum.xml: 47043 words → 189 chunks
#   009_Hilarius-Pictaviensis_Tractatus-super-psalmos.xml: 213739 words → 855 chunks
#   010_Hilarius-Pictaviensis_Fragmenta-ex-aliis-operibus.xml: 748 words → 3 chunks
#   010_Hilarius-Pictaviensis_Liber-primus-ad-Constantium-Augustum.xml: 1266 words → 6 chunks
#   stoa0149b.stoa003.opp-lat1.xml: 1695 words → 7 chunks
#   stoa0149b.stoa004.opp-lat1.xml: 11 words (no chunking)
#   029_Eusebius-Pamphilus_Canones-Evangeliorum.xml: 740 words → 3 chunks
#   008_Eusebius-Pamphilus_Vita-Constantini.xml: 28698 words → 115 chunks
#   Thomas-Aquinas_De-perfectione.xml: 23636 words → 95 chunks
#   Thomas-Aquinas_Officium_Sapientia.xml: 8611 words → 35 chunks
#   Thomas-Aquinas_Super-de-trinitate.xml: 42708 words → 171 chunks
#   Thomas-Aquinas_In-de-divinis-nominibus.xml: 97424 words → 390 chunks
#   Thomas-Aquinas_De-rationibus-fidei.xml: 9446 words → 38 chunks
#   Thomas-Aquinas_Super-Col.xml: 19447 words → 78 chunks
#   Thomas-Aquinas_Quaestio-disputata-de-anima.xml: 61781 words → 248 chunks
#   Thomas-Aquinas_Super-Isaiam.xml: 100830 words → 404 chunks
#   Thomas-Aquinas_De-motu-cordis.xml: 1729 words → 7 chunks
#   Thomas-Aquinas_De-unitate-intellectus.xml: 14461 words → 58 chunks
#   Thomas-Aquinas_Quodlibet.xml: 146664 words → 587 chunks
#   Thomas-Aquinas_In-psalmos-Davidis-expositio.xml: 194767 words → 780 chunks
#   Thomas-Aquinas_De-sortibus.xml: 5163 words → 21 chunks
#   Thomas-Aquinas_De-articulis-fidei.xml: 6482 words → 26 chunks
#   Thomas-Aquinas_De-principiis-naturae.xml: 4335 words → 18 chunks
#   Thomas-Aquinas_De-X-praeceptis.xml: 16456 words → 66 chunks
#   Thomas-Aquinas_Tabula-libri-Ethicorum.xml: 31699 words → 127 chunks
#   Thomas-Aquinas_De-iudiciis-astrorum.xml: 349 words → 2 chunks
#   Thomas-Aquinas_Catena-aurea.xml: 711421 words → 2846 chunks
#   Thomas-Aquinas_Super-IICor.xml: 66427 words → 266 chunks
#   Thomas-Aquinas_Super-Iob.xml: 115382 words → 462 chunks
#   Thomas-Aquinas_Super-IThess.xml: 12500 words → 50 chunks
#   Thomas-Aquinas_Epistola-ad-ducissam-Brabantiae.xml: 1660 words → 7 chunks
#   Thomas-Aquinas_Super-Tit.xml: 12559 words → 51 chunks
#   Thomas-Aquinas_De-substantiis-separatis.xml: 21615 words → 87 chunks
#   Thomas-Aquinas_Sententia-libri-de-sensu-et-sensato.xml: 44578 words → 179 chunks
#   Thomas-Aquinas_Super-IIThess.xml: 8575 words → 35 chunks
#   Thomas-Aquinas_Super-de-gen-et-corr.xml: 22056 words → 89 chunks
#   Thomas-Aquinas_Sententia_libri_Metaphysicae.xml: 260599 words → 1043 chunks
#   Thomas-Aquinas_Super-IITim.xml: 16921 words → 68 chunks
#   Thomas-Aquinas_Super-Eph.xml: 48859 words → 196 chunks
#   Thomas-Aquinas_De-forma-absolutionis.xml: 3698 words → 15 chunks
#   Thomas-Aquinas_Quaestio-disputata-de-virtutibus.xml: 82590 words → 331 chunks
#   Thomas-Aquinas_Super-Phil.xml: 18423 words → 74 chunks
#   Thomas-Aquinas_Super-de-hebdomadibus.xml: 6600 words → 27 chunks
#   Thomas-Aquinas_Super-decretales.xml: 7415 words → 30 chunks
#   Thomas-Aquinas_Sententia-de-anima.xml: 90700 words → 363 chunks
#   Thomas-Aquinas_Super-Jeremiam.xml: 58685 words → 235 chunks
#   Thomas-Aquinas_De-secreto.xml: 795 words → 4 chunks
#   Thomas-Aquinas_Contra-errores-Graecorum.xml: 16605 words → 67 chunks
#   Thomas-Aquinas_De-emptione.xml: 550 words → 3 chunks
#   Thomas-Aquinas_Super-ITim.xml: 27967 words → 112 chunks
#   Thomas-Aquinas_Officium_Sacerdos.xml: 13325 words → 54 chunks
#   Thomas-Aquinas_Quaestio-disputata-de-spiritualibus-creaturis.xml: 36180 words → 145 chunks
#   Thomas-Aquinas_De-mixtione-elementorum.xml: 963 words → 4 chunks
#   Thomas-Aquinas_Super-de-causis.xml: 29703 words → 119 chunks
#   Thomas-Aquinas_Lectura-Romana.xml: 50429 words → 202 chunks
#   Thomas-Aquinas_Super-Ave-Maria.xml: 1669 words → 7 chunks
#   Thomas-Aquinas_Summa-Theologiae.xml: 1630380 words → 6522 chunks
#   Thomas-Aquinas_Super-de-div-nom.xml: 98134 words → 393 chunks
#   Thomas-Aquinas_Super-Iohannem.xml: 320814 words → 1284 chunks
#   Thomas-Aquinas_Conpendium-theologiae.xml: 69898 words → 280 chunks
#   Thomas-Aquinas_In-physicam.xml: 198349 words → 794 chunks
#   Thomas-Aquinas_Super-Philm.xml: 3108 words → 13 chunks
#   Thomas-Aquinas_Summa-contra-gentiles.xml: 282466 words → 1130 chunks
#   Thomas-Aquinas_Contra-impugnantibus-dei.xml: 66753 words → 268 chunks
#   Thomas-Aquinas_Sententia-libri-Ethicorum.xml: 201237 words → 805 chunks
#   Thomas-Aquinas_Responsiones.xml: 19352 words → 78 chunks
#   Thomas-Aquinas_De-potentia.xml: 189777 words → 760 chunks
#   Thomas-Aquinas_De-regno.xml: 13526 words → 55 chunks
#   Thomas-Aquinas_Super-Thren.xml: 12156 words → 49 chunks
#   Thomas-Aquinas_Expositio-Posteriorum.xml: 86950 words → 348 chunks
#   Thomas-Aquinas_De-ente.xml: 7318 words → 30 chunks
#   Thomas-Aquinas_Super-meteora.xml: 40386 words → 162 chunks
#   Thomas-Aquinas_Super-Rom.xml: 131843 words → 528 chunks
#   Thomas-Aquinas_Contra-doctrinam-retrahentium-a-religione.xml: 19406 words → 78 chunks
#   Thomas-Aquinas_Super-ICor.xml: 115693 words → 463 chunks
#   Thomas-Aquinas_Quaestio-disputata-de-unione-verbi.xml: 10555 words → 43 chunks
#   Thomas-Aquinas_Super-Gal.xml: 48703 words → 195 chunks
#   Thomas-Aquinas_Super-de-caelo.xml: 110165 words → 441 chunks
#   Thomas-Aquinas_Scriptum-super-sententiis.xml: 1203516 words → 4815 chunks
#   Thomas-Aquinas_De-operationibus-occultae.xml: 1917 words → 8 chunks
#   Thomas-Aquinas_Expositio-Peryermeneias.xml: 31820 words → 128 chunks
#   Thomas-Aquinas_Sententia-libri-Politicorum.xml: 57339 words → 230 chunks
#   Thomas-Aquinas_Quaestiones-disputatae-de-Veritate.xml: 417055 words → 1669 chunks
#   Thomas-Aquinas_De-malo.xml: 186723 words → 747 chunks
# Successfully extracted 115655 documents (including chunks)
# Total characters: 228,326,518
# Average document length: 1974 characters
# Saved to: ../data/passim/patristic-sources.json
#
# Sample source:
#   ID: Firmicus_Maternus-Mathesis_chunk0
#   Series: FirMat.Mathesi
#   Text preview: Olim tibi hos libellos, Mavorti decus nostrum, me dicaturum esse promiseram, verum diu me inconstantia verecundiae retardavit et ab isto scribendi studio dubia trepidatione revocavit, cum fragilitas i...
#   Metadata: {'title': 'Mathesis', 'author': 'Julius Firmicus Maternusfl.337', 'author_ref': 'http://viaf.org/viaf/10660698', 'series': 'Auctores scientiarum varii', 'series_id': 'FirMat.Mathesi', 'chunk_id': 0, 'parent_id': 'Firmicus_Maternus-Mathesis', 'word_offset': 0}
