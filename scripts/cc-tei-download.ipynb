# %%
import os
import time
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# %%
# CONFIGURATION
CSV_PATH = "../data/church-fathers/church-fathers-gnd-cc.csv"
OUTPUT_BASE = "../data/cc-tei"
BASE_API = "https://mlat.uzh.ch/php_modules/navigate.php?load="
BASE_HOST = "https://mlat.uzh.ch"
BASE_DATA = "https://mlat.uzh.ch/data"
NS = {"cc": "http://mlat.uzh.ch/2.0"}

# HTTP SESSION
session = requests.Session()
session.headers.update({"User-Agent": "tei-downloader/1.1 (+https://example.org)"})


def fetch_xml_root(url: str, max_retries=3, backoff=1.0):
    for attempt in range(1, max_retries + 1):
        try:
            print(f"Fetching: {url}")
            r = session.get(url, timeout=20)
            r.raise_for_status()
            return ET.fromstring(r.content)
        except Exception as e:
            print(f"Warning: fetch failed ({e}), attempt {attempt}/{max_retries}")
            if attempt == max_retries:
                raise
            time.sleep(backoff * attempt)
    raise RuntimeError("unreachable")

# Convert server-side xml path to public URL.
def normalize_xml_path_to_url(xml_path_text: str) -> str:
    if not xml_path_text:
        return None
    s = xml_path_text.strip()

    idx = s.find("/data/")
    if idx != -1:
        data_sub = s[idx:]
        return BASE_HOST + data_sub

    if s.startswith("/var/www/html"):
        idx2 = s.find("/data/")
        if idx2 != -1:
            return BASE_HOST + s[idx2:]
        remainder = s.replace("/var/www/html", "", 1)
        return BASE_HOST + remainder if remainder.startswith("/") else BASE_HOST + "/" + remainder

    if s.startswith("/data"):
        return BASE_HOST + s
    if s.startswith("data/"):
        return BASE_DATA + s[len("data"):]
    return BASE_DATA + "/" + s.lstrip("/")


def get_works_for_author(author_id: str):
    url = f"{BASE_API}{author_id}&group_by="
    root = fetch_xml_root(url)
    works = []
    for w in root.findall(".//cc:work", NS):
        wid = w.findtext("cc:idno", default="", namespaces=NS)
        name = w.findtext("cc:name", default="", namespaces=NS)
        if wid:
            works.append({"id": wid.strip(), "name": name.strip() if name else ""})
    return works


def get_texts_for_work(author_id: str, work_id: str):
    url = f"{BASE_API}{author_id}/{work_id}&group_by="
    root = fetch_xml_root(url)
    texts = []
    for txt in root.findall(".//cc:contents/cc:text", NS):
        tid = txt.findtext("cc:idno", default="", namespaces=NS)
        name = txt.findtext("cc:name", default="", namespaces=NS)
        if tid:
            texts.append({"id": tid.strip(), "name": name.strip() if name else ""})
    return texts


def download_text_xml(author_dir: str, author_id: str, work_id: str, text_id: str):
    if text_id:
        url = f"{BASE_API}{author_id}/{work_id}/{text_id}&group_by="
    else:
        url = f"{BASE_API}{author_id}/{work_id}&group_by="
    root = fetch_xml_root(url)

    xml_path_elem = root.find(".//cc:xml_file_path", NS)
    downloadable_elem = root.find(".//cc:xml_file_downloadable", NS)
    downloadable = True
    if downloadable_elem is not None and downloadable_elem.text:
        downloadable = downloadable_elem.text.strip().lower() == "true"

    if xml_path_elem is None or not xml_path_elem.text or not downloadable:
        print(f"No downloadable TEI at {author_id}/{work_id}/{text_id}")
        return False

    xml_path_text = xml_path_elem.text.strip()
    file_url = normalize_xml_path_to_url(xml_path_text)
    if not file_url:
        print(f"Could not normalize xml path: {xml_path_text}")
        return False

    filename = os.path.basename(file_url)
    out_path = os.path.join(author_dir, filename)

    print(f"Downloading TEI: {file_url}")
    try:
        r = session.get(file_url, timeout=30)
        r.raise_for_status()
        with open(out_path, "wb") as fh:
            fh.write(r.content)
        print(f"Saved: {out_path}")
        return True
    except Exception as e:
        print(f"Download failed: {e}")
        return False


def process_author(author_id: str, author_name: str):
    author_name_sanitized = author_name.replace(" ", "_")
    author_dir = os.path.join(OUTPUT_BASE, author_id)
    os.makedirs(author_dir, exist_ok=True)

    print(f"Downloading TEI XML for {author_name} (ID {author_id})")
    works = get_works_for_author(author_id)
    print(f"Found {len(works)} works for {author_name}.")

    total_downloaded = 0
    for w in works:
        wid = w["id"]
        wname = w.get("name", "")
        print(f"\n→ Work: {wname} (ID {wid})")
        texts = get_texts_for_work(author_id, wid)
        print(f"Found {len(texts)} text(s).")

        if not texts:
            if download_text_xml(author_dir, author_id, wid, ""):
                total_downloaded += 1
            continue

        for t in texts:
            tid = t["id"]
            tname = t.get("name", "")
            print(f"  - Text: {tname} (ID {tid})")
            if download_text_xml(author_dir, author_id, wid, tid):
                total_downloaded += 1
            time.sleep(0.15)
    print(f"Done for {author_name}: {total_downloaded} files saved in {author_dir}")


def main():
    # Load CSV
    df = pd.read_csv(CSV_PATH, sep=';', encoding='utf-8')
    df_with_cc = df[df['cc_id'].notna()].copy()
    print(f"Found {len(df_with_cc)} authors with Corpus Corporum IDs.\n")

    # Iterate through authors
    for _, row in df_with_cc.iterrows():
        cc_id = str(int(row['cc_id']))  # e.g. 876.0 → '876'
        name = row['Name']
        process_author(cc_id, name)
        time.sleep(1)


if __name__ == "__main__":
    main()
# Out:
# Found 28 authors with Corpus Corporum IDs.
#
# Downloading TEI XML for Quintus Septimius Florens Tertullian (ID 867)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867&group_by=
# Found 48 works for Quintus Septimius Florens Tertullian.
#
# → Work: Ad Scapulam (ID 136)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/136&group_by=
# Found 2 text(s).
#   - Text: Responsa ex libris Digestorum (Auctor incertus), J. P. Migne (ID 37)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/136/37&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Auctor-incertus_Responsa-ex-libris-Digestorum.xml
# Saved: ../data/cc-tei/867/001_Auctor-incertus_Responsa-ex-libris-Digestorum.xml
#   - Text: Ad Scapulam (Tertullianus), J. P. Migne (ID 39)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/136/39&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-Scapulam.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_Ad-Scapulam.xml
#
# → Work: Ad martyres (ID 137)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/137&group_by=
# Found 1 text(s).
#   - Text: Ad martyres (Tertullianus), J. P. Migne (ID 40)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/137/40&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-martyres.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_Ad-martyres.xml
#
# → Work: Ad nationes (ID 138)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/138&group_by=
# Found 1 text(s).
#   - Text: Ad nationes (Tertullianus), J. P. Migne (ID 41)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/138/41&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-nationes.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_Ad-nationes.xml
#
# → Work: Ad uxorem (ID 139)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/139&group_by=
# Found 1 text(s).
#   - Text: Ad uxorem (Tertullianus), J. P. Migne (ID 42)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/139/42&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-uxorem.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_Ad-uxorem.xml
#
# → Work: Apologeticus adversus gentes (ID 140)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/140&group_by=
# Found 1 text(s).
#   - Text: Apologeticus adversus gentes (Tertullianus), J. P. Migne (ID 43)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/140/43&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Apologeticus-adversus-gentes.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_Apologeticus-adversus-gentes.xml
#
# → Work: De baptismo (ID 141)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/141&group_by=
# Found 1 text(s).
#   - Text: De baptismo (Tertullianus), J. P. Migne (ID 44)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/141/44&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-baptismo.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_De-baptismo.xml
#
# → Work: De cultu feminarum (ID 142)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/142&group_by=
# Found 1 text(s).
#   - Text: De cultu feminarum (Tertullianus), J. P. Migne (ID 45)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/142/45&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-cultu-feminarum.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_De-cultu-feminarum.xml
#
# → Work: De idololatria (ID 143)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/143&group_by=
# Found 1 text(s).
#   - Text: De idololatria (Tertullianus), J. P. Migne (ID 46)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/143/46&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-idololatria.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_De-idololatria.xml
#
# → Work: De oratione (ID 144)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/144&group_by=
# Found 1 text(s).
#   - Text: De oratione (Tertullianus), J. P. Migne (ID 47)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/144/47&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-oratione.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_De-oratione.xml
#
# → Work: De patientia (ID 145)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/145&group_by=
# Found 1 text(s).
#   - Text: De patientia (Tertullianus), J. P. Migne (ID 48)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/145/48&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-patientia.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_De-patientia.xml
#
# → Work: De poenitentia (ID 146)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/146&group_by=
# Found 1 text(s).
#   - Text: De poenitentia (Tertullianus), J. P. Migne (ID 49)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/146/49&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-poenitentia.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_De-poenitentia.xml
#
# → Work: De testimonio animae (ID 147)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/147&group_by=
# Found 1 text(s).
#   - Text: De testimonio animae (Tertullianus), J. P. Migne (ID 50)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/147/50&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-testimonio-animae.xml
# Saved: ../data/cc-tei/867/001_Tertullianus_De-testimonio-animae.xml
#
# → Work: Adversus Hermogenem (ID 158)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/158&group_by=
# Found 1 text(s).
#   - Text: Adversus Hermogenem (Tertullianus), J. P. Migne (ID 61)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/158/61&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Hermogenem.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_Adversus-Hermogenem.xml
#
# → Work: Adversus Judaeos (ID 159)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/159&group_by=
# Found 1 text(s).
#   - Text: Adversus Judaeos (Tertullianus), J. P. Migne (ID 62)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/159/62&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Judaeos.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_Adversus-Judaeos.xml
#
# → Work: Adversus Marcionem (ID 160)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/160&group_by=
# Found 1 text(s).
#   - Text: Adversus Marcionem (Tertullianus), J. P. Migne (ID 63)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/160/63&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Marcionem.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_Adversus-Marcionem.xml
#
# → Work: Adversus Praxeam (ID 161)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/161&group_by=
# Found 1 text(s).
#   - Text: Adversus Praxeam (Tertullianus), J. P. Migne (ID 64)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/161/64&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Praxeam.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_Adversus-Praxeam.xml
#
# → Work: Adversus Valentinianos (ID 162)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/162&group_by=
# Found 1 text(s).
#   - Text: Adversus Valentinianos (Tertullianus), J. P. Migne (ID 65)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/162/65&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Valentinianos.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_Adversus-Valentinianos.xml
#
# → Work: De anima (ID 163)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/163&group_by=
# Found 1 text(s).
#   - Text: De anima (Tertullianus), J. P. Migne (ID 66)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/163/66&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-anima.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-anima.xml
#
# → Work: De carne Christi (ID 164)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/164&group_by=
# Found 1 text(s).
#   - Text: De carne Christi (Tertullianus), J. P. Migne (ID 67)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/164/67&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-carne-Christi.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-carne-Christi.xml
#
# → Work: De corona militis (ID 165)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/165&group_by=
# Found 1 text(s).
#   - Text: De corona militis (Tertullianus), J. P. Migne (ID 68)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/165/68&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-corona-militis.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-corona-militis.xml
#
# → Work: De exhortatione castitatis (ID 166)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/166&group_by=
# Found 1 text(s).
#   - Text: De exhortatione castitatis (Tertullianus), J. P. Migne (ID 69)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/166/69&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-exhortatione-castitatis.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-exhortatione-castitatis.xml
#
# → Work: De fuga in persecutione (ID 167)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/167&group_by=
# Found 1 text(s).
#   - Text: De fuga in persecutione (Tertullianus), J. P. Migne (ID 70)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/167/70&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-fuga-in-persecutione.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-fuga-in-persecutione.xml
#
# → Work: De jejuniis (ID 168)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/168&group_by=
# Found 1 text(s).
#   - Text: De jejuniis (Tertullianus), J. P. Migne (ID 71)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/168/71&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-jejuniis.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-jejuniis.xml
#
# → Work: De monogamia (ID 169)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/169&group_by=
# Found 1 text(s).
#   - Text: De monogamia (Tertullianus), J. P. Migne (ID 72)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/169/72&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-monogamia.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-monogamia.xml
#
# → Work: De praescriptionibus adversus haereticos (ID 170)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/170&group_by=
# Found 1 text(s).
#   - Text: De praescriptionibus adversus haereticos (Tertullianus), J. P. Migne (ID 73)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/170/73&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-praescriptionibus-adversus-haereticos.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-praescriptionibus-adversus-haereticos.xml
#
# → Work: De pudicitia (ID 171)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/171&group_by=
# Found 1 text(s).
#   - Text: De pudicitia (Tertullianus), J. P. Migne (ID 74)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/171/74&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-pudicitia.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-pudicitia.xml
#
# → Work: De resurrectione carnis (ID 172)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/172&group_by=
# Found 1 text(s).
#   - Text: De resurrectione carnis (Tertullianus), J. P. Migne (ID 75)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/172/75&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-resurrectione-carnis.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-resurrectione-carnis.xml
#
# → Work: De virginibus velandis (ID 173)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/173&group_by=
# Found 1 text(s).
#   - Text: De virginibus velandis (Tertullianus), J. P. Migne (ID 76)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/173/76&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-virginibus-velandis.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_De-virginibus-velandis.xml
#
# → Work: Scorpiace adversus Gnosticos (ID 174)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/174&group_by=
# Found 1 text(s).
#   - Text: Scorpiace adversus Gnosticos (Tertullianus), J. P. Migne (ID 77)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/174/77&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Scorpiace-adversus-Gnosticos.xml
# Saved: ../data/cc-tei/867/002_Tertullianus_Scorpiace-adversus-Gnosticos.xml
#
# → Work: Apologeticum (ID 12371)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12371&group_by=
# Found 1 text(s).
#   - Text: Apologeticum (Tertullianus), Tertullian-Minucius Felix (ID 12596)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12371/12596&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus5_Latinitias_antiqua/Tertullianus_Apologeticum.xml
# Saved: ../data/cc-tei/867/Tertullianus_Apologeticum.xml
#
# → Work: De Spectaculis (ID 12400)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12400&group_by=
# Found 1 text(s).
#   - Text: De Spectaculis (Tertullianus), Tertullian-Minucius Felix (ID 12628)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12400/12628&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus5_Latinitias_antiqua/Tertullianus_De-Spectaculis.xml
# Saved: ../data/cc-tei/867/Tertullianus_De-Spectaculis.xml
#
# → Work: Ad nationes [CSEL] (ID 15059)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15059&group_by=
# Found 1 text(s).
#   - Text: Ad nationes [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14787)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15059/14787&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa002.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa002.opp-lat2.xml
#
# → Work: Adversus Hermogenem [CSEL] (ID 15061)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15061&group_by=
# Found 1 text(s).
#   - Text: Adversus Hermogenem [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14789)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15061/14789&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa004.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa004.opp-lat2.xml
#
# → Work: Adversus Marcionem [CSEL] (ID 15062)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15062&group_by=
# Found 1 text(s).
#   - Text: Adversus Marcionem [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14790)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15062/14790&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa006.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa006.opp-lat2.xml
#
# → Work: Adversus Praxeam [CSEL] (ID 15063)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15063&group_by=
# Found 1 text(s).
#   - Text: Adversus Praxeam [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14791)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15063/14791&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa007.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa007.opp-lat2.xml
#
# → Work: Adversus Valentinianos [CSEL] (ID 15064)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15064&group_by=
# Found 1 text(s).
#   - Text: Adversus Valentinianos [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14792)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15064/14792&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa008.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa008.opp-lat2.xml
#
# → Work: Adversus omnes haereses [CSEL] (ID 15067)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15067&group_by=
# Found 1 text(s).
#   - Text: Adversus omnes haereses [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14795)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15067/14795&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0276.stoa003.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0276.stoa003.opp-lat2.xml
#
# → Work: De anima [CSEL] (ID 15135)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15135&group_by=
# Found 1 text(s).
#   - Text: De anima [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14864)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15135/14864&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa010.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa010.opp-lat2.xml
#
# → Work: De baptismo [CSEL] (ID 15137)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15137&group_by=
# Found 1 text(s).
#   - Text: De baptismo [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14866)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15137/14866&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa011.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa011.opp-lat2.xml
#
# → Work: De carnis resurrectione [CSEL] (ID 15142)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15142&group_by=
# Found 1 text(s).
#   - Text: De carnis resurrectione [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14871)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15142/14871&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa026.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa026.opp-lat2.xml
#
# → Work: De idololatria [CSEL] (ID 15163)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15163&group_by=
# Found 1 text(s).
#   - Text: De idololatria [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14892)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15163/14892&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa017.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa017.opp-lat2.xml
#
# → Work: De ieiunio [CSEL] (ID 15164)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15164&group_by=
# Found 1 text(s).
#   - Text: De ieiunio [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14893)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15164/14893&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa018.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa018.opp-lat2.xml
#
# → Work: De oratione [CSEL] (ID 15185)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15185&group_by=
# Found 1 text(s).
#   - Text: De oratione [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14914)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15185/14914&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa020.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa020.opp-lat2.xml
#
# → Work: De patientia [CSEL] (ID 15188)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15188&group_by=
# Found 1 text(s).
#   - Text: De patientia [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14917)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15188/14917&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa023.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa023.opp-lat2.xml
#
# → Work: De pudicitia [CSEL] (ID 15192)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15192&group_by=
# Found 1 text(s).
#   - Text: De pudicitia [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14921)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15192/14921&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa025.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa025.opp-lat2.xml
#
# → Work: De scorpiace [CSEL] (ID 15198)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15198&group_by=
# Found 1 text(s).
#   - Text: De scorpiace [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14927)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15198/14927&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa030.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa030.opp-lat2.xml
#
# → Work: De spectaculis [CSEL] (ID 15203)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15203&group_by=
# Found 1 text(s).
#   - Text: De spectaculis [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14932)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15203/14932&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa027.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa027.opp-lat2.xml
#
# → Work: De testimonio animae [CSEL] (ID 15206)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15206&group_by=
# Found 1 text(s).
#   - Text: De testimonio animae [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14935)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15206/14935&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa028.opp-lat2.xml
# Saved: ../data/cc-tei/867/stoa0275.stoa028.opp-lat2.xml
# Done for Quintus Septimius Florens Tertullian: 49 files saved in ../data/cc-tei/867
# Downloading TEI XML for Origenes (ID 1049)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049&group_by=
# Found 6 works for Origenes.
#
# → Work: Interpretatio homiliarum Origenis in Canticum canticorum (ID 608)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/608&group_by=
# Found 1 text(s).
#   - Text: Interpretatio homiliarum Origenis in Canticum canticorum (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7164)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/608/7164&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/023_Origenes_-Hieronymus-Stridonensis_Interpretatio-homiliarum-Origenis-in-Canticum-canticorum.xml
# Saved: ../data/cc-tei/1049/023_Origenes_-Hieronymus-Stridonensis_Interpretatio-homiliarum-Origenis-in-Canticum-canticorum.xml
#
# → Work: Translatio homiliarum in visiones Isaiae (ID 616)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/616&group_by=
# Found 1 text(s).
#   - Text: Translatio homiliarum in visiones Isaiae (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7172)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/616/7172&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/024_Origenes_-Hieronymus-Stridonensis_Translatio-homiliarum-in-visiones-Isaiae.xml
# Saved: ../data/cc-tei/1049/024_Origenes_-Hieronymus-Stridonensis_Translatio-homiliarum-in-visiones-Isaiae.xml
#
# → Work: Translatio Homiliarum in Jeremiam et Ezechielem (ID 626)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/626&group_by=
# Found 1 text(s).
#   - Text: Translatio Homiliarum in Jeremiam et Ezechielem (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7182)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/626/7182&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/025_Origenes_-Hieronymus-Stridonensis_Translatio-Homiliarum-in-Jeremiam-et-Ezechielem.xml
# Saved: ../data/cc-tei/1049/025_Origenes_-Hieronymus-Stridonensis_Translatio-Homiliarum-in-Jeremiam-et-Ezechielem.xml
#
# → Work: Translatio XXXIX Homiliarum (ID 636)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/636&group_by=
# Found 1 text(s).
#   - Text: Translatio XXXIX Homiliarum (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7192)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/636/7192&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/026_Origenes_-Hieronymus-Stridonensis_Translatio-XXXIX-Homiliarum.xml
# Saved: ../data/cc-tei/1049/026_Origenes_-Hieronymus-Stridonensis_Translatio-XXXIX-Homiliarum.xml
#
# → Work: De incarnatione Verbi (ID 2463)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/2463&group_by=
# Found 1 text(s).
#   - Text: De incarnatione Verbi (Origenes), J. P. Migne (ID 7448)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/2463/7448&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/042_Origenes_De-incarnatione-Verbi.xml
# Saved: ../data/cc-tei/1049/042_Origenes_De-incarnatione-Verbi.xml
#
# → Work: De principiis (ID 21749)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/21749&group_by=
# Found 1 text(s).
#   - Text: De Principiis (Origenes, trans. Rufinus), Méquignon-Havard (ID 21750)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/21749/21750&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus10_Philosophica/Origenes_De-principiis.xml
# Saved: ../data/cc-tei/1049/Origenes_De-principiis.xml
# Done for Origenes: 6 files saved in ../data/cc-tei/1049
# Downloading TEI XML for Eusebius von Caesarea (ID 919)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919&group_by=
# Found 2 works for Eusebius von Caesarea.
#
# → Work: Vita Constantini (ID 288)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/288&group_by=
# Found 1 text(s).
#   - Text: Vita Constantini (Eusebius Pamphilus), J. P. Migne (ID 6843)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/288/6843&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/008_Eusebius-Pamphilus_Vita-Constantini.xml
# Saved: ../data/cc-tei/919/008_Eusebius-Pamphilus_Vita-Constantini.xml
#
# → Work: Canones Evangeliorum (ID 664)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/664&group_by=
# Found 1 text(s).
#   - Text: Canones Evangeliorum (Eusebius Pamphilus), J. P. Migne (ID 7221)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/664/7221&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/029_Eusebius-Pamphilus_Canones-Evangeliorum.xml
# Saved: ../data/cc-tei/919/029_Eusebius-Pamphilus_Canones-Evangeliorum.xml
# Done for Eusebius von Caesarea: 2 files saved in ../data/cc-tei/919
# Downloading TEI XML for Hilarius von Poitiers (ID 927)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927&group_by=
# Found 28 works for Hilarius von Poitiers.
#
# → Work: Commentarius in Matthaeum (ID 308)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/308&group_by=
# Found 1 text(s).
#   - Text: Commentarius in Matthaeum (Hilarius Pictaviensis), J. P. Migne (ID 6863)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/308/6863&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/009_Hilarius-Pictaviensis_Commentarius-in-Matthaeum.xml
# Saved: ../data/cc-tei/927/009_Hilarius-Pictaviensis_Commentarius-in-Matthaeum.xml
#
# → Work: Commentarius in psalmos XV XXXI XLI (ID 309)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/309&group_by=
# Found 1 text(s).
#   - Text: Commentarius in psalmos XV XXXI XLI (Hilarius Pictaviensis), J. P. Migne (ID 6864)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/309/6864&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/009_Hilarius-Pictaviensis_Commentarius-in-psalmos-XV-XXXI-XLI.xml
# Saved: ../data/cc-tei/927/009_Hilarius-Pictaviensis_Commentarius-in-psalmos-XV-XXXI-XLI.xml
#
# → Work: Apologetica responsa ad reprehensores libri de synodis (ID 315)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/315&group_by=
# Found 1 text(s).
#   - Text: Apologetica responsa ad reprehensores libri de synodis (Hilarius Pictaviensis), J. P. Migne (ID 6870)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/315/6870&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Apologetica-responsa-ad-reprehensores-libri-de-synodis.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Apologetica-responsa-ad-reprehensores-libri-de-synodis.xml
#
# → Work: De Trinitate (ID 316)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/316&group_by=
# Found 1 text(s).
#   - Text: De Trinitate (Hilarius Pictaviensis), J. P. Migne (ID 6871)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/316/6871&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_De-Trinitate.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_De-Trinitate.xml
#
# → Work: Epistola ad Abram (ID 317)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/317&group_by=
# Found 1 text(s).
#   - Text: Epistola ad Abram (Hilarius Pictaviensis), J. P. Migne (ID 6872)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/317/6872&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Epistola-ad-Abram.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Epistola-ad-Abram.xml
#
# → Work: Epistola seu libellus (ID 318)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/318&group_by=
# Found 1 text(s).
#   - Text: Epistola seu libellus (Hilarius Pictaviensis), J. P. Migne (ID 6873)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/318/6873&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Epistola-seu-libellus.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Epistola-seu-libellus.xml
#
# → Work: Fragmenta ex opere historico (ID 319)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/319&group_by=
# Found 1 text(s).
#   - Text: Fragmenta ex opere historico (Hilarius Pictaviensis), J. P. Migne (ID 6874)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/319/6874&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Fragmenta-ex-opere-historico.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Fragmenta-ex-opere-historico.xml
#
# → Work: Hymnus Abrae missus (ID 320)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/320&group_by=
# Found 1 text(s).
#   - Text: Hymnus Abrae missus (Hilarius Pictaviensis), J. P. Migne (ID 6875)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/320/6875&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Hymnus-Abrae-missus.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Hymnus-Abrae-missus.xml
#
# → Work: Liber contra Arianos vel Auxentium (ID 321)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/321&group_by=
# Found 1 text(s).
#   - Text: Liber contra Arianos vel Auxentium (Hilarius Pictaviensis), J. P. Migne (ID 6876)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/321/6876&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Liber-contra-Arianos-vel-Auxentium.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Liber-contra-Arianos-vel-Auxentium.xml
#
# → Work: Liber contra Constantium (ID 322)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/322&group_by=
# Found 1 text(s).
#   - Text: Liber contra Constantium (Hilarius Pictaviensis), J. P. Migne (ID 6877)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/322/6877&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Liber-contra-Constantium.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Liber-contra-Constantium.xml
#
# → Work: Liber de synodis seu fide orientalium (ID 323)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/323&group_by=
# Found 1 text(s).
#   - Text: Liber de synodis seu fide orientalium (Hilarius Pictaviensis), J. P. Migne (ID 6878)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/323/6878&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Liber-de-synodis-seu-fide-orientalium.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Liber-de-synodis-seu-fide-orientalium.xml
#
# → Work: Liber primus ad Constantium Augustum (ID 324)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/324&group_by=
# Found 1 text(s).
#   - Text: Liber primus ad Constantium Augustum (Hilarius Pictaviensis), J. P. Migne (ID 6879)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/324/6879&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Liber-primus-ad-Constantium-Augustum.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Liber-primus-ad-Constantium-Augustum.xml
#
# → Work: Liber secundus ad Constantium (ID 325)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/325&group_by=
# Found 1 text(s).
#   - Text: Liber secundus ad Constantium (Hilarius Pictaviensis), J. P. Migne (ID 6880)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/325/6880&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Liber-secundus-ad-Constantium.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Liber-secundus-ad-Constantium.xml
#
# → Work: Sermo de dedicatione ecclesiae (ID 326)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/326&group_by=
# Found 1 text(s).
#   - Text: Sermo de dedicatione ecclesiae (Hilarius Pictaviensis), J. P. Migne (ID 6881)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/326/6881&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Sermo-de-dedicatione-ecclesiae.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Sermo-de-dedicatione-ecclesiae.xml
#
# → Work: Collectanea antiariana parisina (Fragmenta historica) [CSEL] (ID 15092)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15092&group_by=
# Found 1 text(s).
#   - Text: Collectanea antiariana parisina (Fragmenta historica) [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14821)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15092/14821&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa002.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa002.opp-lat1.xml
#
# → Work: De evangelio [CSEL] (ID 15154)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15154&group_by=
# Found 1 text(s).
#   - Text: De evangelio [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14883)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15154/14883&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149p.stoa001.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149p.stoa001.opp-lat1.xml
#
# → Work: De martyrio Maccabaeorum [CSEL] (ID 15172)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15172&group_by=
# Found 1 text(s).
#   - Text: De martyrio Maccabaeorum [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14901)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15172/14901&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149p.stoa002.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149p.stoa002.opp-lat1.xml
#
# → Work: Fragmenta minora [CSEL] (ID 15253)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15253&group_by=
# Found 1 text(s).
#   - Text: Fragmenta minora [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14984)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15253/14984&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa003.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa003.opp-lat1.xml
#
# → Work: Hymni [CSEL] (ID 15259)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15259&group_by=
# Found 1 text(s).
#   - Text: Hymni [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14990)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15259/14990&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa004.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa004.opp-lat1.xml
#
# → Work: In Genesin [CSEL] (ID 15262)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15262&group_by=
# Found 1 text(s).
#   - Text: In Genesin [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14993)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15262/14993&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149p.stoa003.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149p.stoa003.opp-lat1.xml
#
# → Work: Liber ad Constantium Imperatorem [CSEL] (ID 15273)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15273&group_by=
# Found 1 text(s).
#   - Text: Liber ad Constantium Imperatorem [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15004)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15273/15004&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa005.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa005.opp-lat1.xml
#
# → Work: Libri tres adversum Valentem et Ursacium [CSEL] (ID 15280)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15280&group_by=
# Found 1 text(s).
#   - Text: Libri tres adversum Valentem et Ursacium [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15011)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15280/15011&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa006.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa006.opp-lat1.xml
#
# → Work: Oratio Synodi Sardicensis ad Constantium Imperatorem [CSEL] (ID 15288)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15288&group_by=
# Found 1 text(s).
#   - Text: Oratio Synodi Sardicensis ad Constantium Imperatorem [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15019)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15288/15019&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa007.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa007.opp-lat1.xml
#
# → Work: Spuria [CSEL] (ID 15308)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15308&group_by=
# Found 1 text(s).
#   - Text: Spuria [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15039)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15308/15039&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa008.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa008.opp-lat1.xml
#
# → Work: Tractatus mysteriorum [CSEL] (ID 15312)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15312&group_by=
# Found 1 text(s).
#   - Text: Tractatus mysteriorum [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15043)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15312/15043&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa009.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa009.opp-lat1.xml
#
# → Work: Tractatus super psalmos [CSEL] (ID 15313)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15313&group_by=
# Found 1 text(s).
#   - Text: Tractatus super psalmos [CSEL] (Hilarius Pictaviensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15044)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/15313/15044&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0149b.stoa001.opp-lat1.xml
# Saved: ../data/cc-tei/927/stoa0149b.stoa001.opp-lat1.xml
#
# → Work: Fragmenta ex aliis operibus (ID 21521)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/21521&group_by=
# Found 1 text(s).
#   - Text: Fragmenta ex aliis operibus (Hilarius Pictaviensis), J. P. Migne (ID 21406)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/21521/21406&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/010_Hilarius-Pictaviensis_Fragmenta-ex-aliis-operibus.xml
# Saved: ../data/cc-tei/927/010_Hilarius-Pictaviensis_Fragmenta-ex-aliis-operibus.xml
#
# → Work: Tractatus super psalmos (ID 21560)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/21560&group_by=
# Found 1 text(s).
#   - Text: Tractatus super psalmos (Hilarius Pictaviensis), J. P. Migne (ID 21450)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/21560/21450&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/009_Hilarius-Pictaviensis_Tractatus-super-psalmos.xml
# Saved: ../data/cc-tei/927/009_Hilarius-Pictaviensis_Tractatus-super-psalmos.xml
# Done for Hilarius von Poitiers: 28 files saved in ../data/cc-tei/927
# Downloading TEI XML for Athanasius von Alexandrien (ID 938)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938&group_by=
# Found 5 works for Athanasius von Alexandrien.
#
# → Work: Epistolae ad Luciferum (ID 346)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/346&group_by=
# Found 1 text(s).
#   - Text: Epistolae ad Luciferum (Athanasius Alexandrinus), J. P. Migne (ID 6901)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/346/6901&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/013_Athanasius-Alexandrinus_Epistolae-ad-Luciferum.xml
# Saved: ../data/cc-tei/938/013_Athanasius-Alexandrinus_Epistolae-ad-Luciferum.xml
#
# → Work: Epistola ad Luciferum (ID 2730)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/2730&group_by=
# Found 1 text(s).
#   - Text: Epistola ad Luciferum (Athanasius Alexandrinus), J. P. Migne (ID 7722)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/2730/7722&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/062_Athanasius-Alexandrinus_Epistola-ad-Luciferum.xml
# Saved: ../data/cc-tei/938/062_Athanasius-Alexandrinus_Epistola-ad-Luciferum.xml
#
# → Work: Vita B. Antonii abbatis (ID 2996)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/2996&group_by=
# Found 1 text(s).
#   - Text: Vita B. Antonii abbatis (Athanasius Alexandrinus; Evagrius Antiochensis), J. P. Migne (ID 7996)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/2996/7996&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/073_Athanasius-Alexandrinus_-Evagrius-Antiochensis_Vita-B.-Antonii-abbatis.xml
# Saved: ../data/cc-tei/938/073_Athanasius-Alexandrinus_-Evagrius-Antiochensis_Vita-B.-Antonii-abbatis.xml
#
# → Work: De observationibus monachorum (ID 3717)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/3717&group_by=
# Found 1 text(s).
#   - Text: De observationibus monachorum (Athanasius Alexandrinus), J. P. Migne (ID 8740)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/3717/8740&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/103_Athanasius-Alexandrinus_De-observationibus-monachorum.xml
# Saved: ../data/cc-tei/938/103_Athanasius-Alexandrinus_De-observationibus-monachorum.xml
#
# → Work: Exhortatio ad sponsam Christi (ID 3718)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/3718&group_by=
# Found 1 text(s).
#   - Text: Exhortatio ad sponsam Christi (Athanasius Alexandrinus), J. P. Migne (ID 8741)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=938/3718/8741&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/103_Athanasius-Alexandrinus_Exhortatio-ad-sponsam-Christi.xml
# Saved: ../data/cc-tei/938/103_Athanasius-Alexandrinus_Exhortatio-ad-sponsam-Christi.xml
# Done for Athanasius von Alexandrien: 5 files saved in ../data/cc-tei/938
# Downloading TEI XML for Basilius der Grosse (Caesariensis) (ID 1472)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472&group_by=
# Found 5 works for Basilius der Grosse (Caesariensis).
#
# → Work: Prologus in librum Psalmorum (ID 772)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/772&group_by=
# Found 1 text(s).
#   - Text: Prologus in librum Psalmorum (Basilius Caesareae; Rufinus Aquileiensis), J. P. Migne (ID 7330)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/772/7330&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/036_Basilius-Caesareae_-Rufinus-Aquileiensis_Prologus-in-librum-Psalmorum.xml
# Saved: ../data/cc-tei/1472/036_Basilius-Caesareae_-Rufinus-Aquileiensis_Prologus-in-librum-Psalmorum.xml
#
# → Work: Admonitio ad filium spiritualem (ID 3721)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/3721&group_by=
# Found 1 text(s).
#   - Text: Admonitio ad filium spiritualem (Basilius Caesareae), J. P. Migne (ID 8744)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/3721/8744&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/103_Basilius-Caesareae_Admonitio-ad-filium-spiritualem.xml
# Saved: ../data/cc-tei/1472/103_Basilius-Caesareae_Admonitio-ad-filium-spiritualem.xml
#
# → Work: Regula S. Basilii (ID 3722)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/3722&group_by=
# Found 1 text(s).
#   - Text: Regula S. Basilii (Basilius Caesareae), J. P. Migne (ID 8745)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/3722/8745&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/103_Basilius-Caesareae_Regula-S.-Basilii.xml
# Saved: ../data/cc-tei/1472/103_Basilius-Caesareae_Regula-S.-Basilii.xml
#
# → Work: Epistulae (ID 22295)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/22295&group_by=
# Found 1 text(s).
#   - Text: Epistulae (Basilius), William Heinemann; G.P. Putnam's Sons (ID 22987)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/22295/22987&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/CorpusG_Graeca_miscellanea/tlg2040.tlg004.perseus-grc1.xml
# Saved: ../data/cc-tei/1472/tlg2040.tlg004.perseus-grc1.xml
#
# → Work: De poetis legendis (ID 22394)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/22394&group_by=
# Found 1 text(s).
#   - Text: De poetis legendis (Basilius), William Heinemann; G.P. Putnam's Sons (ID 23087)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1472/22394/23087&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/CorpusG_Graeca_miscellanea/tlg2040.tlg002.perseus-grc1.xml
# Saved: ../data/cc-tei/1472/tlg2040.tlg002.perseus-grc1.xml
# Done for Basilius der Grosse (Caesariensis): 5 files saved in ../data/cc-tei/1472
# Downloading TEI XML for Ambrosius von Mailand (ID 958)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=958&group_by=
# Found 62 works for Ambrosius von Mailand.
#
# ...
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Quodlibet.xml
#
# → Work: Quaestiones disputatae de malo (ID 12097)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12097&group_by=
# Found 1 text(s).
#   - Text: Quaestiones disputatae de malo (Thomas Aquinas), ed. Textum Taurini (ID 12021)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12097/12021&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_De-malo.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_De-malo.xml
#
# → Work: Quaestiones disputatae de potentia (ID 12098)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12098&group_by=
# Found 1 text(s).
#   - Text: Quaestiones disputatae de potentia (Thomas Aquinas), ed. Textum Taurini (ID 12022)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12098/12022&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_De-potentia.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_De-potentia.xml
#
# → Work: Quaestiones disputatae de veritate (ID 12099)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12099&group_by=
# Found 1 text(s).
#   - Text: Quaestiones disputatae de veritate (Thomas Aquinas), ed. Textum Leoninum (ID 12023)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12099/12023&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Quaestiones-disputatae-de-Veritate.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Quaestiones-disputatae-de-Veritate.xml
#
# → Work: Quaestiones disputatae de virtutibus (ID 12100)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12100&group_by=
# Found 1 text(s).
#   - Text: Quaestiones disputatae de virtutibus (Thomas Aquinas), ed. Textum Taurini (ID 12024)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12100/12024&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Quaestio-disputata-de-virtutibus.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Quaestio-disputata-de-virtutibus.xml
#
# → Work: Responsiones (ID 12101)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12101&group_by=
# Found 1 text(s).
#   - Text: Responsiones (Thomas Aquinas), ed. Textum Taurini (ID 12025)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12101/12025&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Responsiones.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Responsiones.xml
#
# → Work: Scriptum super Sententiis (ID 12102)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12102&group_by=
# Found 1 text(s).
#   - Text: Scriptum super Sententiis (Thomas Aquinas), ed. Textum Leoninum (ID 12026)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12102/12026&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Scriptum-super-sententiis.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Scriptum-super-sententiis.xml
#
# → Work: Sentencia libri De anima (ID 12103)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12103&group_by=
# Found 1 text(s).
#   - Text: Sentencia libri De anima (Thomas Aquinas), ed. Textum Taurini (ID 12027)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12103/12027&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Sententia-de-anima.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Sententia-de-anima.xml
#
# → Work: Sentencia libri De sensu et sensato (ID 12104)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12104&group_by=
# Found 1 text(s).
#   - Text: Sentencia libri De sensu et sensato (Thomas Aquinas), ed. Textum Taurini (ID 12028)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12104/12028&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Sententia-libri-de-sensu-et-sensato.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Sententia-libri-de-sensu-et-sensato.xml
#
# → Work: Sentencia super Meteora, lib. 1-2 cap. 10 (ID 12105)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12105&group_by=
# Found 1 text(s).
#   - Text: Sentencia super Meteora, lib. 1-2 cap. 10 (Thomas Aquinas), ed. Textum Leoninum (ID 12029)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12105/12029&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-meteora.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-meteora.xml
#
# → Work: Sententia libri Ethicorum (ID 12106)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12106&group_by=
# Found 1 text(s).
#   - Text: Sententia libri Ethicorum (Thomas Aquinas), ed. Editio Leonina (ID 12030)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12106/12030&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Sententia-libri-Ethicorum.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Sententia-libri-Ethicorum.xml
#
# → Work: Sententia libri Metaphysicae (ID 12107)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12107&group_by=
# Found 1 text(s).
#   - Text: Sententia libri Metaphysicae (Thomas Aquinas), ed. Textum Taurini (ID 12031)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12107/12031&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Sententia_libri_Metaphysicae.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Sententia_libri_Metaphysicae.xml
#
# → Work: Sententia libri Politicorum (ID 12108)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12108&group_by=
# Found 1 text(s).
#   - Text: Sententia libri Politicorum (Thomas Aquinas), ed. Editio Leonina (ID 12032)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12108/12032&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Sententia-libri-Politicorum.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Sententia-libri-Politicorum.xml
#
# → Work: Summa Theologiae (ID 12109)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12109&group_by=
# Found 1 text(s).
#   - Text: Summa Theologiae (Thomas Aquinas), ed. Textum Leoninum (ID 12033)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12109/12033&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Summa-Theologiae.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Summa-Theologiae.xml
#
# → Work: Summa contra gentiles (ID 12110)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12110&group_by=
# Found 1 text(s).
#   - Text: Summa contra gentiles (Thomas Aquinas), ed. Textum Leoninum (ID 12034)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12110/12034&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Summa-contra-gentiles.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Summa-contra-gentiles.xml
#
# → Work: Super De caelo lectura (ID 12111)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12111&group_by=
# Found 1 text(s).
#   - Text: Super De caelo lectura (Thomas Aquinas), ed. Textum Leoninum (ID 12035)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12111/12035&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-de-caelo.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-de-caelo.xml
#
# → Work: Super De causis (ID 12112)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12112&group_by=
# Found 1 text(s).
#   - Text: Super De causis (Thomas Aquinas), ed. H.-D. Saffrey (ID 12036)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12112/12036&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-de-causis.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-de-causis.xml
#
# → Work: Super Decretales (ID 12113)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12113&group_by=
# Found 1 text(s).
#   - Text: Super Decretales (Thomas Aquinas), ed. Textum Leoninum (ID 12037)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12113/12037&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-decretales.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-decretales.xml
#
# → Work: Super Epistolam B.
# 	Pauli ad Colossenses lectura (ID 12114)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12114&group_by=
# Found 1 text(s).
#   - Text: Super Epistolam B.
# 	Pauli ad Colossenses lectura (Thomas Aquinas), ed. Textum Leoninum (ID 12038)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12114/12038&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Col.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Col.xml
#
# → Work: Super Epistolam B.
# 	Pauli ad Ephesios lectura (ID 12115)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12115&group_by=
# Found 1 text(s).
#   - Text: Super Epistolam B.
# 	Pauli ad Ephesios lectura (Thomas Aquinas), ed. Textum Taurini (ID 12039)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12115/12039&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Eph.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Eph.xml
#
# → Work: Super Epistolam B.
# 	Pauli ad Galatas lectura (ID 12116)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12116&group_by=
# Found 1 text(s).
#   - Text: Super Epistolam B.
# 	Pauli ad Galatas lectura (Thomas Aquinas), ed. Textum Taurini (ID 12040)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12116/12040&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Gal.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Gal.xml
#
# → Work: Super Epistolam B.
# 	Pauli ad Philemonem lectura (ID 12117)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12117&group_by=
# Found 1 text(s).
#   - Text: Super Epistolam B.
# 	Pauli ad Philemonem lectura (Thomas Aquinas), ed. Textum Taurini (ID 12041)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12117/12041&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Philm.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Philm.xml
#
# → Work: Super Epistolam B.
# 	Pauli ad Philipenses lectura (ID 12118)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12118&group_by=
# Found 1 text(s).
#   - Text: Super Epistolam B.
# 	Pauli ad Philipenses lectura (Thomas Aquinas), ed. Textum Taurini (ID 12042)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12118/12042&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Phil.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Phil.xml
#
# → Work: Super Epistolam B.
# 	Pauli ad Romanos lectura (ID 12119)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12119&group_by=
# Found 1 text(s).
#   - Text: Super Epistolam B.
# 	Pauli ad Romanos lectura (Thomas Aquinas), ed. Textum Taurini (ID 12043)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12119/12043&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Rom.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Rom.xml
#
# → Work: Super Epistolam B.
# 	Pauli ad Titum lectura (ID 12120)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12120&group_by=
# Found 1 text(s).
#   - Text: Super Epistolam B.
# 	Pauli ad Titum lectura (Thomas Aquinas), ed. Textum Taurini (ID 12044)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12120/12044&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Tit.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Tit.xml
#
# → Work: Super Evangelium S.
# 	Ioannis lectura (ID 12121)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12121&group_by=
# Found 1 text(s).
#   - Text: Super Evangelium S.
# 	Ioannis lectura (Thomas Aquinas), ed. Textum Taurini (ID 12045)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12121/12045&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-Iohannem.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-Iohannem.xml
#
# → Work: Super I Epistolam B.
# 	Pauli ad Thessalonicenses lectura (ID 12122)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12122&group_by=
# Found 1 text(s).
#   - Text: Super I Epistolam B.
# 	Pauli ad Thessalonicenses lectura (Thomas Aquinas), ed. Textum Leoninum (ID 12046)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12122/12046&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-IThess.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-IThess.xml
#
# → Work: Super I Epistolam B.
# 	Pauli ad Timotheum lectura (ID 12123)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12123&group_by=
# Found 1 text(s).
#   - Text: Super I Epistolam B.
# 	Pauli ad Timotheum lectura (Thomas Aquinas), ed. Textum Taurini (ID 12047)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12123/12047&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-ITim.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-ITim.xml
#
# → Work: Super I Epistolam ad Corinthios lectura (ID 12124)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12124&group_by=
# Found 1 text(s).
#   - Text: Super I Epistolam ad Corinthios lectura (Thomas Aquinas), ed. Textum Leoninum (ID 12048)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12124/12048&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-ICor.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-ICor.xml
#
# → Work: Super II Epistolam B.
# 	Pauli ad Thessalonicenses lectura (ID 12125)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12125&group_by=
# Found 1 text(s).
#   - Text: Super II Epistolam B.
# 	Pauli ad Thessalonicenses lectura (Thomas Aquinas), ed. Textum Leoninum (ID 12049)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12125/12049&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-IIThess.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-IIThess.xml
#
# → Work: Super II Epistolam B.
# 	Pauli ad Timotheum lectura (ID 12126)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12126&group_by=
# Found 1 text(s).
#   - Text: Super II Epistolam B.
# 	Pauli ad Timotheum lectura (Thomas Aquinas), ed. Textum Taurini (ID 12050)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12126/12050&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-IITim.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-IITim.xml
#
# → Work: Super II Epistolam ad Corinthios lectura (ID 12127)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12127&group_by=
# Found 1 text(s).
#   - Text: Super II Epistolam ad Corinthios lectura (Thomas Aquinas), ed. Textum Leoninum (ID 12051)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12127/12051&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Super-IICor.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Super-IICor.xml
#
# → Work: Tabula libri Ethicorum (ID 12128)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12128&group_by=
# Found 1 text(s).
#   - Text: Tabula libri Ethicorum (Thomas Aquinas), ed. Editio Leonina (ID 12052)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=12129/12128/12052&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus3_Aquinas/Thomas-Aquinas_Tabula-libri-Ethicorum.xml
# Saved: ../data/cc-tei/12129/Thomas-Aquinas_Tabula-libri-Ethicorum.xml
# Done for Thomas von Aquin: 77 files saved in ../data/cc-tei/12129
