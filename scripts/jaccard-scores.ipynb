# %%
import json
from pathlib import Path
from collections import defaultdict
from cltk.alphabet.lat import normalize_lat
from cltk.nlp import NLP

# %%
def setup_cltk():
    """Initialise CLTK for Latin."""
    nlp = NLP(language="lat")
    print("CLTK initialized successfully.\n")
    return nlp


def lemmatize_latin(text, nlp):
    """Lemmatise Latin text using CLTK."""
    text = normalize_lat(text)
    doc = nlp.analyze(text)
    
    lemmas = []
    for word in doc.words:
        if hasattr(word, 'lemma') and word.lemma:
            lemmas.append(word.lemma.lower())
        else:
            lemmas.append(word.string.lower())
    
    return set(lemmas)


def tokenize_latin(text, nlp):
    """Tokenise Latin text and return list of tokens (not lemmas)"""
    text = normalize_lat(text)
    doc = nlp.analyze(text)
    
    tokens = []
    for word in doc.words:
        tokens.append(word.string.lower())
    
    return tokens


def is_latin(text):
    """
    Detect if text is primarily Latin.
    Returns True if text contains mostly Latin characters and common Latin words.
    """
    latin_indicators = ['est', 'sunt', 'et', 'non', 'in', 'ut', 'ad', 'per', 'cum', 
                        'sed', 'qui', 'quae', 'quod', 'esse', 'sit', 'de']
    
    text_lower = text.lower()
    
    has_latin_indicator = any(indicator in text_lower for indicator in latin_indicators)
    
    latin_chars = sum(1 for c in text if c.isalpha() and ord(c) < 591)
    total_chars = sum(1 for c in text if c.isalpha())
    
    if total_chars == 0:
        return False
    
    latin_ratio = latin_chars / total_chars if total_chars > 0 else 0
    
    return has_latin_indicator and latin_ratio > 0.9


def jaccard_coefficient(set1, set2):
    """Calculate Jaccard coefficient between two sets."""
    if len(set1) == 0 and len(set2) == 0:
        return 0.0
    
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    
    return intersection / union if union > 0 else 0.0


def analyze_jaccard_from_validation(validation_json_path):
    """Main analysis function using validation_annotations.json"""
    
    print("JACCARD SIMILARITY ANALYSIS")
    print("=" * 80)
    print()
    
    # Load validation annotations
    with open(validation_json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    annotations = data['annotations']
    
    print(f"Loaded {len(annotations)} annotations from validation dataset")
    print(f"Processing Latin annotations...\n")
    
    # Initialize CLTK
    nlp = setup_cltk()
    
    # Collect results
    all_results = []
    latin_count = 0
    non_latin_count = 0
    
    # Process each annotation
    for i, ann in enumerate(annotations, 1):
        letter_text = ann.get('letter_text', '')
        patristic_text = ann.get('patristic_text', '')
        
        if not letter_text or not patristic_text:
            continue
        
        # Check if both texts are Latin
        if not (is_latin(letter_text) and is_latin(patristic_text)):
            non_latin_count += 1
            continue
        
        latin_count += 1
        
        if latin_count % 10 == 0:
            print(f"Processed {latin_count} Latin annotations...", end='\r', flush=True)
        
        # Tokenize for length analysis
        letter_tokens_list = tokenize_latin(letter_text, nlp)
        patristic_tokens_list = tokenize_latin(patristic_text, nlp)
        
        # Lemmatize for Jaccard calculation
        letter_lemmas = lemmatize_latin(letter_text, nlp)
        patristic_lemmas = lemmatize_latin(patristic_text, nlp)
        
        # Calculate Jaccard coefficient (on lemmas)
        jaccard = jaccard_coefficient(letter_lemmas, patristic_lemmas)
        
        # Calculate overlap stats (on lemmas)
        intersection = letter_lemmas.intersection(patristic_lemmas)
        union = letter_lemmas.union(patristic_lemmas)
        
        # Store results
        result = {
            'letter_id': ann.get('letter_id'),
            'reference_type': ann.get('reference_type', 'unknown'),
            'church_father': ann.get('church_fathers', 'unknown'),
            'confidence': ann.get('confidence', 'unknown'),
            'detection_source': ann.get('detection_source', 'unknown'),
            'jaccard': jaccard,
            'letter_token_count': len(letter_tokens_list),
            'patristic_token_count': len(patristic_tokens_list),
            'letter_lemma_count': len(letter_lemmas),
            'patristic_lemma_count': len(patristic_lemmas),
            'intersection': len(intersection),
            'union': len(union),
            'letter_span': letter_text[:100] + '...' if len(letter_text) > 100 else letter_text
        }
        
        all_results.append(result)
    
    print()
    print(f"Completed processing!")
    print(f"  - Latin annotations: {latin_count}")
    print(f"  - Non-Latin (skipped): {non_latin_count}")
    print()
    
    if not all_results:
        print("No Latin annotations found to analyze!")
        return
    
    # ==================== STATISTICS ====================
    
    # JACCARD SIMILARITY
    print("JACCARD SIMILARITY ANALYSIS (Lemma-Based)")
    print("-" * 80)
    
    jaccards = [r['jaccard'] for r in all_results]
    avg_jaccard = sum(jaccards) / len(jaccards)
    
    print(f"Total Latin annotations analysed: {len(all_results)}")
    print(f"Average Jaccard coefficient: {avg_jaccard:.4f}")
    print(f"Min Jaccard: {min(jaccards):.4f}")
    print(f"Max Jaccard: {max(jaccards):.4f}")
    print(f"Median Jaccard: {sorted(jaccards)[len(jaccards)//2]:.4f}")
    print()
    
    # TOKEN LENGTH STATISTICS
    print("TOKEN LENGTH ANALYSIS (Token-Based)")
    print("-" * 80)
    
    letter_token_counts = [r['letter_token_count'] for r in all_results]
    patristic_token_counts = [r['patristic_token_count'] for r in all_results]
    
    print("LETTER SPAN TOKEN STATISTICS:")
    print(f"  Average tokens: {sum(letter_token_counts) / len(letter_token_counts):.2f}")
    print(f"  Min tokens: {min(letter_token_counts)}")
    print(f"  Max tokens: {max(letter_token_counts)}")
    print(f"  Median tokens: {sorted(letter_token_counts)[len(letter_token_counts)//2]}")
    print()
    
    print("PATRISTIC TEXT TOKEN STATISTICS:")
    print(f"  Average tokens: {sum(patristic_token_counts) / len(patristic_token_counts):.2f}")
    print(f"  Min tokens: {min(patristic_token_counts)}")
    print(f"  Max tokens: {max(patristic_token_counts)}")
    print(f"  Median tokens: {sorted(patristic_token_counts)[len(patristic_token_counts)//2]}")
    print()
    
    # LEMMA OVERLAP
    print("LEMMA OVERLAP STATISTICS")
    print("-" * 80)
    
    avg_letter_lemmas = sum(r['letter_lemma_count'] for r in all_results) / len(all_results)
    avg_patristic_lemmas = sum(r['patristic_lemma_count'] for r in all_results) / len(all_results)
    avg_intersection = sum(r['intersection'] for r in all_results) / len(all_results)
    avg_union = sum(r['union'] for r in all_results) / len(all_results)
    
    print(f"Average letter span lemmas: {avg_letter_lemmas:.2f}")
    print(f"Average patristic text lemmas: {avg_patristic_lemmas:.2f}")
    print(f"Average intersection size: {avg_intersection:.2f}")
    print(f"Average union size: {avg_union:.2f}")
    print()
    
    # ANALYSIS BY REFERENCE TYPE
    print("ANALYSIS BY REFERENCE TYPE")
    print("-" * 80)
    
    by_ref_type = defaultdict(lambda: {'jaccards': [], 'letter_tokens': [], 'patristic_tokens': []})
    for result in all_results:
        ref_type = result['reference_type']
        by_ref_type[ref_type]['jaccards'].append(result['jaccard'])
        by_ref_type[ref_type]['letter_tokens'].append(result['letter_token_count'])
        by_ref_type[ref_type]['patristic_tokens'].append(result['patristic_token_count'])
    
    print(f"{'Type':<15s} {'Count':>8s} {'Avg Jaccard':>12s} {'Avg Letter Tokens':>18s} {'Avg Patristic Tokens':>20s}")
    print("-" * 80)
    
    for ref_type in sorted(by_ref_type.keys()):
        data = by_ref_type[ref_type]
        count = len(data['jaccards'])
        avg_jacc = sum(data['jaccards']) / count
        avg_lett = sum(data['letter_tokens']) / count
        avg_patr = sum(data['patristic_tokens']) / count
        
        print(f"{ref_type:<15s} {count:8d} {avg_jacc:12.4f} {avg_lett:18.2f} {avg_patr:20.2f}")
    
    print()
    
    # TOP/BOTTOM JACCARD SCORES
    sorted_results = sorted(all_results, key=lambda x: x['jaccard'], reverse=True)
    
    print("TOP 10 HIGHEST JACCARD SCORES")
    print("-" * 90)
    print(f"{'Letter':<12s} {'Type':<10s} {'Jaccard':>10s} {'Tokens(L/P)':>15s} {'Preview':<40s}")
    print("-" * 90)
    
    for result in sorted_results[:10]:
        letter_id = result['letter_id']
        ref_type = result['reference_type']
        jaccard = result['jaccard']
        tokens_str = f"{result['letter_token_count']}/{result['patristic_token_count']}"
        preview = result['letter_span'][:37] + '...' if len(result['letter_span']) > 37 else result['letter_span']
        
        print(f"{letter_id:<12s} {ref_type:<10s} {jaccard:10.4f} {tokens_str:>15s} {preview:<40s}")
    
    print()
    
    print("TOP 10 LOWEST JACCARD SCORES")
    print("-" * 90)
    print(f"{'Letter':<12s} {'Type':<10s} {'Jaccard':>10s} {'Tokens(L/P)':>15s} {'Preview':<40s}")
    print("-" * 90)
    
    for result in sorted_results[-10:]:
        letter_id = result['letter_id']
        ref_type = result['reference_type']
        jaccard = result['jaccard']
        tokens_str = f"{result['letter_token_count']}/{result['patristic_token_count']}"
        preview = result['letter_span'][:37] + '...' if len(result['letter_span']) > 37 else result['letter_span']
        
        print(f"{letter_id:<12s} {ref_type:<10s} {jaccard:10.4f} {tokens_str:>15s} {preview:<40s}")
    
    print()


if __name__ == "__main__":
    validation_path = Path("../annotations/evaluation-dataset/validation_annotations.json")
    analyze_jaccard_from_validation(validation_path)
# Out:
# JACCARD SIMILARITY ANALYSIS
# ...
#
# Loaded 100 annotations from validation dataset
# Processing Latin annotations...
#
# ‎𐤀 CLTK version '1.5.0'. When using the CLTK in research, please cite: https://aclanthology.org/2021.acl-demo.3/
#
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinLexiconProcess`.
#
# ⸖ ``LatinStanzaProcess`` using Stanza model from the Stanford NLP Group: https://stanfordnlp.github.io/stanza/ . Please cite: https://arxiv.org/abs/2003.07082
# ⸖ ``LatinEmbeddingsProcess`` using word2vec model by University of Oslo from http://vectors.nlpl.eu/ . Please cite: https://aclanthology.org/W17-0237/
# ⸖ ``LatinLexiconProcess`` using Lewis's *An Elementary Latin Dictionary* (1890).
#
# ⸎ To suppress these messages, instantiate ``NLP()`` with ``suppress_banner=True``.
# CLTK initialized successfully.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# ...
