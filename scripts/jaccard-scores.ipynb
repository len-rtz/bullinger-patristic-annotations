# %%
import json
import csv
from pathlib import Path
from collections import Counter, defaultdict
import re
from cltk import NLP
from cltk.alphabet.lat import normalize_lat

# %%
def setup_cltk():
    """Initialize CLTK for Latin."""

    nlp = NLP(language="lat")
    print("CLTK initialized successfully.\n")
    return nlp


def lemmatize_latin(text, nlp):
    """Lemmatize Latin text using CLTK."""

    # Normalize and process
    text = normalize_lat(text)
    doc = nlp.analyze(text)
        
    # Extract lemmas
    lemmas = []
    for word in doc.words:
        if hasattr(word, 'lemma') and word.lemma:
            lemmas.append(word.lemma.lower())
        else:
            lemmas.append(word.string.lower())
        
    return set(lemmas)

def is_latin(text):
    """
    Detect if text is primarily Latin.
    Returns True if text contains mostly Latin characters and common Latin words.
    """
    # Latin words as indicators
    latin_indicators = ['est', 'sunt', 'et', 'non', 'in', 'ut', 'ad', 'per', 'cum', 
                        'sed', 'qui', 'quae', 'quod', 'esse', 'sit', 'de']
    
    text_lower = text.lower()
    
    # Check if at least one Latin indicator is present
    has_latin_indicator = any(indicator in text_lower for indicator in latin_indicators)
    
    # Check if text is primarily Latin alphabet (excluding Greek, High New German, etc.)
    latin_chars = sum(1 for c in text if c.isalpha() and ord(c) < 591)  # Basic Latin + Latin Extended
    total_chars = sum(1 for c in text if c.isalpha())
    
    if total_chars == 0:
        return False
    
    latin_ratio = latin_chars / total_chars if total_chars > 0 else 0
    
    return has_latin_indicator and latin_ratio > 0.9

def jaccard_coefficient(set1, set2):
    """Calculate Jaccard coefficient between two sets."""
    if len(set1) == 0 and len(set2) == 0:
        return 0.0
    
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    
    return intersection / union if union > 0 else 0.0


def find_json_files(base_path):
    """Recursively find all JSON files."""
    return list(Path(base_path).rglob("*.json"))


def extract_text_from_json(json_file):
    """Extract the full text (sofaString) from JSON file."""
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # Find the sofaString in the Sofa object
    if isinstance(data, dict):
        for key, value in data.items():
            if isinstance(value, list):
                for item in value:
                    if isinstance(item, dict) and item.get('%TYPE') == 'uima.cas.Sofa':
                        return item.get('sofaString', '')
    return ''


def extract_annotations(json_file):
    """Extract PatristicReference annotations from JSON."""
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    annotations = []
    
    if isinstance(data, dict):
        for key, value in data.items():
            if isinstance(value, list):
                for item in value:
                    if isinstance(item, dict) and item.get('%TYPE') == 'webanno.custom.PatristicReference':
                        annotations.append(item)
    
    return annotations


def analyze_jaccard(base_path):
    """Main analysis function."""
    

    print("Annotation Jaccard Analysis")

    print()
    
    # Initialize CLTK
    nlp = setup_cltk()
    
    # Find all JSON files
    json_files = find_json_files(base_path)
    print(f"Found {len(json_files)} JSON files")
    print(f"Processing annotations (lemmatizing only annotated spans)...\n")
    
    # Collect results
    all_results = []
    latin_count = 0
    non_latin_count = 0
    processed_files = 0
    
    # Process each file
    for json_file in json_files:
        try:
            # Get full text (only used to extract the annotated spans by index)
            full_text = extract_text_from_json(json_file)
            if not full_text:
                continue
            
            # Get annotations
            annotations = extract_annotations(json_file)
            
            if annotations:
                processed_files += 1
                print(f"Processing letter {json_file.parent.name} ({processed_files} with annotations)... ", end='', flush=True)
                
                file_annotation_count = 0
            
            if annotations:
                processed_files += 1
                print(f"Processing letter {processed_files}/{len(json_files)}: {json_file.parent.name} ({len(annotations)} annotations)")
            
            for ann in annotations:
                # Extract annotation data
                begin = ann.get('begin')
                end = ann.get('end')
                patristic_text = ann.get('patristic_text', '')
                reference_type = ann.get('reference_type', 'unknown')
                church_father = ann.get('church_fathers', 'unknown')
                confidence = ann.get('confidence', 'unknown')
                detection_source = ann.get('detection_source', 'unknown')
                
                if begin is None or end is None or not patristic_text:
                    continue
                
                # Extract letter text span (ONLY the annotated portion - much faster!)
                letter_span = full_text[begin:end]
                
                # Check if both texts are Latin
                if not (is_latin(letter_span) and is_latin(patristic_text)):
                    non_latin_count += 1
                    continue
                
                latin_count += 1
                file_annotation_count += 1
                
                # Lemmatize both texts
                letter_tokens = lemmatize_latin(letter_span, nlp)
                patristic_tokens = lemmatize_latin(patristic_text, nlp)
                
                # Calculate Jaccard coefficient
                jaccard = jaccard_coefficient(letter_tokens, patristic_tokens)
                
                # Calculate overlap stats
                intersection = letter_tokens.intersection(patristic_tokens)
                union = letter_tokens.union(patristic_tokens)
                
                # Store results
                result = {
                    'letter_id': json_file.parent.name,
                    'reference_type': reference_type,
                    'church_father': church_father,
                    'confidence': confidence,
                    'detection_source': detection_source,
                    'jaccard': jaccard,
                    'letter_tokens': len(letter_tokens),
                    'patristic_tokens': len(patristic_tokens),
                    'intersection': len(intersection),
                    'union': len(union),
                    'letter_span': letter_span[:100] + '...' if len(letter_span) > 100 else letter_span
                }
                
                all_results.append(result)
            
            if file_annotation_count > 0:
                print(f"✓ {file_annotation_count} Latin annotations")
        
        except Exception as e:
            print(f"\n⚠ Error processing {json_file}: {e}")
    
    print()
    print(f"Completed processing!")
    print(f"  - Letters processed: {processed_files}")
    print(f"  - Latin annotations: {latin_count}")
    print(f"  - Non-Latin (skipped): {non_latin_count}")
    print()
    
    if not all_results:
        print("No Latin annotations found to analyze!")
        return
    
    # Calculate overall statistics
    jaccards = [r['jaccard'] for r in all_results]
    avg_jaccard = sum(jaccards) / len(jaccards)
    
    print(f"Total Latin annotations analyzed: {len(all_results)}")
    print(f"Average Jaccard coefficient: {avg_jaccard:.4f}")
    print(f"Min Jaccard: {min(jaccards):.4f}")
    print(f"Max Jaccard: {max(jaccards):.4f}")
    print(f"Median Jaccard: {sorted(jaccards)[len(jaccards)//2]:.4f}")
    print()
    
    # Token overlap statistics

    print("Token overlap statistics")

    
    avg_letter_tokens = sum(r['letter_tokens'] for r in all_results) / len(all_results)
    avg_patristic_tokens = sum(r['patristic_tokens'] for r in all_results) / len(all_results)
    avg_intersection = sum(r['intersection'] for r in all_results) / len(all_results)
    avg_union = sum(r['union'] for r in all_results) / len(all_results)
    
    print(f"Average letter span tokens: {avg_letter_tokens:.2f}")
    print(f"Average patristic text tokens: {avg_patristic_tokens:.2f}")
    print(f"Average intersection size: {avg_intersection:.2f}")
    print(f"Average union size: {avg_union:.2f}")
    print()
    
    # Analysis by reference type
    print("Analysis by reference type")
    
    by_ref_type = defaultdict(list)
    for result in all_results:
        by_ref_type[result['reference_type']].append(result['jaccard'])
    
    print(f"{'Reference Type':<20s} {'Count':>8s} {'Avg Jaccard':>15s} {'Min':>10s} {'Max':>10s}")
    
    for ref_type in sorted(by_ref_type.keys()):
        jaccards = by_ref_type[ref_type]
        count = len(jaccards)
        avg = sum(jaccards) / count
        min_j = min(jaccards)
        max_j = max(jaccards)
        print(f"{ref_type:<20s} {count:8d} {avg:15.4f} {min_j:10.4f} {max_j:10.4f}")
    
    print()
    
    # Show top 10 highest Jaccard scores
    print("Top 10 highest Jaccard scores")
    
    sorted_results = sorted(all_results, key=lambda x: x['jaccard'], reverse=True)
    
    print(f"{'Letter':<12s} {'Type':<10s} {'Jaccard':>10s} {'Tokens(L/P)':>15s} {'Preview':<40s}")
    
    for result in sorted_results[10:]:
        letter_id = result['letter_id']
        ref_type = result['reference_type']
        jaccard = result['jaccard']
        tokens_str = f"{result['letter_tokens']}/{result['patristic_tokens']}"
        preview = result['letter_span'][:37] + '...' if len(result['letter_span']) > 37 else result['letter_span']
        
        print(f"{letter_id:<12s} {ref_type:<10s} {jaccard:10.4f} {tokens_str:>15s} {preview:<40s}")
    
    print()
    
    # Show top 10 lowest Jaccard scores
    print("Top 10 lowest Jaccard Scores")

    print(f"{'Letter':<12s} {'Type':<10s} {'Jaccard':>10s} {'Tokens(L/P)':>15s} {'Preview':<40s}")

    for result in sorted_results[-10:]:
        letter_id = result['letter_id']
        ref_type = result['reference_type']
        jaccard = result['jaccard']
        tokens_str = f"{result['letter_tokens']}/{result['patristic_tokens']}"
        preview = result['letter_span'][:37] + '...' if len(result['letter_span']) > 37 else result['letter_span']
        
        print(f"{letter_id:<12s} {ref_type:<10s} {jaccard:10.4f} {tokens_str:>15s} {preview:<40s}")
    
    print()

    print("All Jaccard Scores")
    sorted_results = sorted(all_results, key=lambda x: x['jaccard'], reverse=True)
    print(f"{'#':<4s} {'Letter':<12s} {'Type':<10s} {'Jaccard':>10s} {'Tokens(L/P)':>15s} {'Preview':<40s}")

    for i, result in enumerate(sorted_results, 1):
        letter_id = result['letter_id']
        ref_type = result['reference_type']
        jaccard = result['jaccard']
        tokens_str = f"{result['letter_tokens']}/{result['patristic_tokens']}"
        preview = result['letter_span'][:37] + '...' if len(result['letter_span']) > 37 else result['letter_span']
    
        print(f"{i:<4d} {letter_id:<12s} {ref_type:<10s} {jaccard:10.4f} {tokens_str:>15s} {preview:<40s}")

    print()


if __name__ == "__main__":
    base_path = "/Users/lenap/Desktop/Master-Thesis/bullinger-patristic-annotations/annotations/annotations-json"
    analyze_jaccard(base_path)
# Out:
# Annotation Jaccard Analysis
#
# ‎𐤀 CLTK version '1.5.0'. When using the CLTK in research, please cite: https://aclanthology.org/2021.acl-demo.3/
#
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinLexiconProcess`.
#
# ⸖ ``LatinStanzaProcess`` using Stanza model from the Stanford NLP Group: https://stanfordnlp.github.io/stanza/ . Please cite: https://arxiv.org/abs/2003.07082
# ⸖ ``LatinEmbeddingsProcess`` using word2vec model by University of Oslo from http://vectors.nlpl.eu/ . Please cite: https://aclanthology.org/W17-0237/
# ⸖ ``LatinLexiconProcess`` using Lewis's *An Elementary Latin Dictionary* (1890).
#
# ⸎ To suppress these messages, instantiate ``NLP()`` with ``suppress_banner=True``.
# CLTK initialized successfully.
#
# Found 67 JSON files
# Processing annotations (lemmatizing only annotated spans)...
#
# Processing letter 12805.txt (1 with annotations)... Processing letter 2/67: 12805.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 12408.txt (3 with annotations)... Processing letter 4/67: 12408.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 9183.txt (5 with annotations)... Processing letter 6/67: 9183.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 11507.txt (7 with annotations)... Processing letter 8/67: 11507.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 2 Latin annotations
# Processing letter 9780.txt (9 with annotations)... Processing letter 10/67: 9780.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 3904.txt (11 with annotations)... Processing letter 12/67: 3904.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 13088.txt (13 with annotations)... Processing letter 14/67: 13088.txt (5 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 5 Latin annotations
# Processing letter 10768.txt (15 with annotations)... Processing letter 16/67: 10768.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 11689.txt (17 with annotations)... Processing letter 18/67: 11689.txt (3 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 3 Latin annotations
# Processing letter 1888.txt (19 with annotations)... Processing letter 20/67: 1888.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 3425.txt (21 with annotations)... Processing letter 22/67: 3425.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 12046.txt (23 with annotations)... Processing letter 24/67: 12046.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Variant' with value 'Greek'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Variant' with value 'Greek'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 10484.txt (25 with annotations)... Processing letter 26/67: 10484.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 2 Latin annotations
# Processing letter 12697.txt (27 with annotations)... Processing letter 28/67: 12697.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 10041.txt (29 with annotations)... Processing letter 30/67: 10041.txt (4 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 3 Latin annotations
# Processing letter 13004.txt (31 with annotations)... Processing letter 32/67: 13004.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 11820.txt (33 with annotations)... Processing letter 34/67: 11820.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 2 Latin annotations
# Processing letter 11968.txt (35 with annotations)... Processing letter 36/67: 11968.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 10478.txt (37 with annotations)... Processing letter 38/67: 10478.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 11148.txt (39 with annotations)... Processing letter 40/67: 11148.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 10518.txt (41 with annotations)... Processing letter 42/67: 10518.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 7325.txt (43 with annotations)... Processing letter 44/67: 7325.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 2 Latin annotations
# Processing letter 11372.txt (45 with annotations)... Processing letter 46/67: 11372.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 12874.txt (47 with annotations)... Processing letter 48/67: 12874.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 10454.txt (49 with annotations)... Processing letter 50/67: 10454.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 11212.txt (51 with annotations)... Processing letter 52/67: 11212.txt (1 annotations)
# Processing letter 11818.txt (53 with annotations)... Processing letter 54/67: 11818.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 11171.txt (55 with annotations)... Processing letter 56/67: 11171.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 10053.txt (57 with annotations)... Processing letter 58/67: 10053.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 12334.txt (59 with annotations)... Processing letter 60/67: 12334.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 2 Latin annotations
# Processing letter 11826.txt (61 with annotations)... Processing letter 62/67: 11826.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 10286.txt (63 with annotations)... Processing letter 64/67: 10286.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 2 Latin annotations
# Processing letter 12080.txt (65 with annotations)... Processing letter 66/67: 12080.txt (3 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 3 Latin annotations
# Processing letter 11990.txt (67 with annotations)... Processing letter 68/67: 11990.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 10936.txt (69 with annotations)... Processing letter 70/67: 10936.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 11194.txt (71 with annotations)... Processing letter 72/67: 11194.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 11751.txt (73 with annotations)... Processing letter 74/67: 11751.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 11976.txt (75 with annotations)... Processing letter 76/67: 11976.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 6187.txt (77 with annotations)... Processing letter 78/67: 6187.txt (2 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 2 Latin annotations
# Processing letter 11591.txt (79 with annotations)... Processing letter 80/67: 11591.txt (3 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized value 'Lit' for UD feature 'NameType'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 3 Latin annotations
# Processing letter 10857.txt (81 with annotations)... Processing letter 82/67: 10857.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 12265.txt (83 with annotations)... Processing letter 84/67: 12265.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 11022.txt (85 with annotations)... Processing letter 86/67: 11022.txt (1 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 1 Latin annotations
# Processing letter 10506.txt (87 with annotations)... Processing letter 88/67: 10506.txt (1 annotations)
# ✓ 1 Latin annotations
# Processing letter 3405.txt (89 with annotations)... Processing letter 90/67: 3405.txt (3 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# ✓ 3 Latin annotations
# Processing letter 11593.txt (91 with annotations)... Processing letter 92/67: 11593.txt (4 annotations)
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# If you believe this is not an error in the dependency parser, please raise an issue at <https://github.com/cltk/cltk/issues> and include a short text to reproduce the error.
#
# Unrecognized UD feature 'Compound' with value 'Yes'.
# ...
# 11591.txt    explicit       0.5873           42/58 „Venturus“, inquit, „est ad vivos mor...
# 10041.txt    explicit       0.5778           34/37 Non enim inter homines caro eius, qui...
# 13088.txt    explicit       0.5593           53/39 „Quid igitur didicit Ioannes, inquit,...
# 11593.txt    explicit       0.5551         154/199 „Veram Christi humanitatem“, inquit, ...
# 11150.txt    explicit       0.5321          62/105 Quomodo reges domino serviunt in timo...
# 11507.txt    explicit       0.5263           14/15 neque bonum neque malum est; sive eni...
# 10041.txt    explicit       0.5000            10/8 Ergo splendori gloriae non permisceas...
# 11689.txt    explicit       0.4675           59/54 „Obtestor te coram deo et domino nost...
# 3904.txt     explicit       0.4409           67/67 Ac per hoc, qui non manet in Christo ...
# 10857.txt    implicit       0.2800            7/25 non aquam, sed spiritum lavare animam
# 12334.txt    explicit       0.2593           13/21 Oportet Christum esse in uno coeli lo...
# 11591.txt    implicit       0.2500           10/10 Quid autem Athenis aut Sorbonae cum H...
# 12265.txt    implicit       0.2353            8/13 verbum elemento accedere tantum, non ...
# 11507.txt    implicit       0.2093           16/36 non aliud in coena vel sequendum vel ...
# 12448.txt    implicit       0.1935           24/50 Ea in re restitit in faciem Petro doc...
# 6284.txt     implicit       0.1905           30/45 quid per unitatem substantiae intelli...
# 10936.txt    implicit       0.1786            9/24 more andabatarum in tenebris ventilar...
# 12697.txt    implicit       0.1765           17/23 Venter voluptates quęrit. Titillant h...
# 12874.txt    implicit       0.1739          109/80 Verbi autem et sacramentorum eadem in...
# 11818.txt    implicit       0.1714           23/18 Deus favet nunc Cliven[si] contra dom...
# 10501.txt    implicit       0.1667            7/21 Sacramentum est invisibilis gratiae v...
# 11337.txt    implicit       0.1667            9/26 Nosti omnibus esse palatum, sed pauci...
# 11522.txt    implicit       0.1667           10/39 Ceterum quod deest, resarciet omnis b...
# 11754.txt    implicit       0.1538           16/14 Sin autem factu minus opus esse arbit...
# 10506.txt    implicit       0.1500           25/21 quas scriptura et vulgatus usus in tr...
# 12408.txt    implicit       0.1438          63/104 Uteris cum aliis verbo exhibendi, cui...
# 11148.txt    implicit       0.1404           45/20 „Ego“, inquit, „vobiscum sum“ [Mt 28,...
# 11022.txt    implicit       0.1379           11/22 Det illis deus mentem saniorem et vob...
# 10478.txt    implicit       0.1333         159/113 Nosti, ut hic religiosus fuerit d[ivu...
# 11623.txt    implicit       0.1304           12/14 sed optandum sit protinus cum illis s...
# 10518.txt    implicit       0.1250            5/13 cum sacramenta sint verba visibilia
# 10404.txt    implicit       0.1250           23/22 Scribere tamen distuli, ne ferventi a...
# 10065.txt    implicit       0.1183           43/61 Nemo negat, cum etiam Iosephus Judaeu...
# 10454.txt    implicit       0.1176          50/102 Cuius errorem ex Pythagora et princip...
# 10484.txt    implicit       0.1163            7/41 Recte enim dictum est deum comprehens...
# 11372.txt    implicit       0.1154            9/20 Crede mihi, non est quies nisi in dom...
# 11751.txt    implicit       0.1143            5/34 deo, omnium bonorum authori
# 10067.txt    implicit       0.1111           79/31 Idcirco suam illam criminum propulsat...
# 11246.txt    implicit       0.1077           22/50 Non hoc tantum nomine, quod summo bon...
# 12805.txt    implicit       0.1053           22/20 N. Recipiunt hic sese tandem in portu...
# 12046.txt    implicit       0.1000          58/118 Quemadmodum d[ivus] Aurelius Augusti[...
# 11755.txt    implicit       0.0976            7/38 Errare possum, hereticus esse nolo.
# 11968.txt    implicit       0.0962           24/33 Quam sententiam caesar contra illum l...
# 11826.txt    implicit       0.0909           12/36 Ad quod respondemus exomologesim ritu...
# 11326.txt    implicit       0.0870           20/30 tertia die resuscitatum et in coelos ...
# 11990.txt    implicit       0.0833           30/22 Interea tamen, ut vere scribis, dissi...
# 12448.txt    implicit       0.0769           25/45 Cum Nazareis aut Mineis eundem Christ...
# 10484.txt    implicit       0.0741            6/52 Dei enim proprium est incomprehensibi...
# 13088.txt    implicit       0.0735           51/22 Absurdum plane dogma est, quod quidam...
# 12080.txt    implicit       0.0714           11/34 Veritas canonica aequat omnes per tot...
# 11171.txt    implicit       0.0667           28/20 Quemadmodum nanque deus per vos, fide...
# 11194.txt    implicit       0.0571           10/27 Speramus tamen illum favente domino n...
# 10511.txt    implicit       0.0526           10/50 unum oris et ventris, alterum animę e...
# 10511.txt    implicit       0.0294            3/32 celeste et terrestre
# 10768.txt    implicit       0.0280           72/75 Aber ich wais nichts witers darzuͦ uf...
# 13004.txt    implicit       0.0278           12/25 Wir muͤssen noch mitt dem hammer alle...
# 10908.txt    implicit       0.0234          19/112 Der münch ist wol gefuͤtert, feyst un...
# 10053.txt    implicit       0.0145           60/10 Dorumb das dises alles vermitten blib...
# 4178.txt     implicit       0.0000            5/20 Tolle spacia locorum corporibus etc.
#
# Top 10 lowest Jaccard Scores
# Letter       Type          Jaccard     Tokens(L/P) Preview
# 12080.txt    implicit       0.0714           11/34 Veritas canonica aequat omnes per tot...
# 11171.txt    implicit       0.0667           28/20 Quemadmodum nanque deus per vos, fide...
# 11194.txt    implicit       0.0571           10/27 Speramus tamen illum favente domino n...
# 10511.txt    implicit       0.0526           10/50 unum oris et ventris, alterum animę e...
# 10511.txt    implicit       0.0294            3/32 celeste et terrestre
# 10768.txt    implicit       0.0280           72/75 Aber ich wais nichts witers darzuͦ uf...
# 13004.txt    implicit       0.0278           12/25 Wir muͤssen noch mitt dem hammer alle...
# 10908.txt    implicit       0.0234          19/112 Der münch ist wol gefuͤtert, feyst un...
# 10053.txt    implicit       0.0145           60/10 Dorumb das dises alles vermitten blib...
# 4178.txt     implicit       0.0000            5/20 Tolle spacia locorum corporibus etc.
#
# All Jaccard Scores
# #    Letter       Type          Jaccard     Tokens(L/P) Preview
# 1    12080.txt    explicit       1.0000           19/19 Adulterari non potest sponsa Christi,...
# 2    7325.txt     explicit       0.9355           30/30 Totum hoc genus rerum liberas habet o...
# 3    3405.txt     explicit       0.9118           32/33 Christum dominum nostrum, unigenitum ...
# 4    2801.txt     explicit       0.8438           55/63 Pater non assumpsit carnem neque spir...
# 5    13088.txt    explicit       0.8407         107/101 Sed nos, inquit, etsi de literis apos...
# 6    13088.txt    explicit       0.8356           66/68 Potuisset dominus noster Iesus Christ...
# 7    13088.txt    explicit       0.8333           61/60 Omnes regni illius homines, ait, ’doc...
# 8    6187.txt     explicit       0.8182           10/10 addit, quia plenitudo deitatis in fil...
# 9    5473.txt     explicit       0.8077           23/24 in deo patre et in filio neque duos c...
# 10   11820.txt    explicit       0.8065           56/56 lla ipsa fides est, quae fideles dei ...
# 11   2801.txt     explicit       0.8049           33/41 Non per hoc mediator est, quod aequal...
# 12   7325.txt     explicit       0.8000           17/19 Mallem in rebus huiusmodi, ut et ille...
# 13   10286.txt    explicit       0.7963           95/99 Ego vero fateor charitati tuae», inqu...
# 14   10067.txt    explicit       0.7955           80/78 Coimus», inquit, «ad divinarum litera...
# 15   9780.txt     explicit       0.7885           46/47 Aliae, ait, sunt leges Caesarum, alia...
# 16   6284.txt     explicit       0.7838           34/32 Dicturus unam substantiam catolicus p...
# 17   10015.txt    explicit       0.7705           54/54 Solent dicere non omnia apostolos sci...
# 18   11689.txt    explicit       0.7654           67/76 Principio tenere te volo, quod est hu...
# 19   11976.txt    explicit       0.7500            12/9 Spatia locorum tolle in corporibus et...
# 20   2801.txt     explicit       0.7423           80/89 Nec eos audiamus, qui dicunt: Si pass...
# 21   11593.txt    explicit       0.7368           33/33 „Christum“, ait, „dominum nostrum, un...
# 22   6187.txt     explicit       0.7273           29/28 Glorificaturus pater filium maior est...
# 23   3405.txt     explicit       0.7273           18/20 Una persona deus et homo est et utrum...
# 24   11593.txt    explicit       0.7273           20/18 „Spatia“, inquit, „locorum tolle corp...
# 25   10015.txt    explicit       0.7222           15/16 Pro modulo meo capio, quod vobis adpo...
# 26   11591.txt    explicit       0.7143           49/59 „Sequester dei et hominum, Christus, ...
# 27   11593.txt    explicit       0.7143           25/23 Hoc est ergo manducare cibum,“ ait, „...
# 28   12080.txt    explicit       0.6667           38/37 „Quisquis“, inquit, „ab ecclesia segr...
# 29   11820.txt    explicit       0.6533         121/127 Si vita aeterna bonis operibus reddit...
# 30   10286.txt    explicit       0.6526           75/82 Ego Originem et nonnullos ecclesiasti...
# 31   3425.txt     explicit       0.6500           29/37 Et si laicus necessitate compulsus ba...
# 32   9183.txt     explicit       0.6486           30/31 Bonus pastor animam suam dat pro ovib...
# 33   2435.txt     explicit       0.6389           59/59 Ac postea, et nos hodie accipimus vis...
# 34   3405.txt     explicit       0.6383           38/39 Merces nostra copiosa est in coelis" ...
# 35   12334.txt    explicit       0.6250             6/7 Immortalitatem dedit; naturam non abs...
# 36   1888.txt     explicit       0.6071           21/24 Propterea namque magna opera domini, ...
# 37   11689.txt    explicit       0.6026           54/71 Sola“, inquit, „catholica ecclesia es...
# 38   10041.txt    explicit       0.5960           67/91 «In regia coelorum sedet adhuc Iesus ...
# 39   11591.txt    explicit       0.5873           42/58 „Venturus“, inquit, „est ad vivos mor...
# 40   10041.txt    explicit       0.5778           34/37 Non enim inter homines caro eius, qui...
# 41   13088.txt    explicit       0.5593           53/39 „Quid igitur didicit Ioannes, inquit,...
# 42   11593.txt    explicit       0.5551         154/199 „Veram Christi humanitatem“, inquit, ...
# 43   11150.txt    explicit       0.5321          62/105 Quomodo reges domino serviunt in timo...
# 44   11507.txt    explicit       0.5263           14/15 neque bonum neque malum est; sive eni...
# 45   10041.txt    explicit       0.5000            10/8 Ergo splendori gloriae non permisceas...
# 46   11689.txt    explicit       0.4675           59/54 „Obtestor te coram deo et domino nost...
# 47   3904.txt     explicit       0.4409           67/67 Ac per hoc, qui non manet in Christo ...
# 48   10857.txt    implicit       0.2800            7/25 non aquam, sed spiritum lavare animam
# 49   12334.txt    explicit       0.2593           13/21 Oportet Christum esse in uno coeli lo...
# 50   11591.txt    implicit       0.2500           10/10 Quid autem Athenis aut Sorbonae cum H...
# 51   12265.txt    implicit       0.2353            8/13 verbum elemento accedere tantum, non ...
# 52   11507.txt    implicit       0.2093           16/36 non aliud in coena vel sequendum vel ...
# 53   12448.txt    implicit       0.1935           24/50 Ea in re restitit in faciem Petro doc...
# 54   6284.txt     implicit       0.1905           30/45 quid per unitatem substantiae intelli...
# 55   10936.txt    implicit       0.1786            9/24 more andabatarum in tenebris ventilar...
# 56   12697.txt    implicit       0.1765           17/23 Venter voluptates quęrit. Titillant h...
# 57   12874.txt    implicit       0.1739          109/80 Verbi autem et sacramentorum eadem in...
# 58   11818.txt    implicit       0.1714           23/18 Deus favet nunc Cliven[si] contra dom...
# 59   10501.txt    implicit       0.1667            7/21 Sacramentum est invisibilis gratiae v...
# 60   11337.txt    implicit       0.1667            9/26 Nosti omnibus esse palatum, sed pauci...
# 61   11522.txt    implicit       0.1667           10/39 Ceterum quod deest, resarciet omnis b...
# 62   11754.txt    implicit       0.1538           16/14 Sin autem factu minus opus esse arbit...
# 63   10506.txt    implicit       0.1500           25/21 quas scriptura et vulgatus usus in tr...
# 64   12408.txt    implicit       0.1438          63/104 Uteris cum aliis verbo exhibendi, cui...
# 65   11148.txt    implicit       0.1404           45/20 „Ego“, inquit, „vobiscum sum“ [Mt 28,...
# 66   11022.txt    implicit       0.1379           11/22 Det illis deus mentem saniorem et vob...
# 67   10478.txt    implicit       0.1333         159/113 Nosti, ut hic religiosus fuerit d[ivu...
# 68   11623.txt    implicit       0.1304           12/14 sed optandum sit protinus cum illis s...
# 69   10518.txt    implicit       0.1250            5/13 cum sacramenta sint verba visibilia
# 70   10404.txt    implicit       0.1250           23/22 Scribere tamen distuli, ne ferventi a...
# 71   10065.txt    implicit       0.1183           43/61 Nemo negat, cum etiam Iosephus Judaeu...
# 72   10454.txt    implicit       0.1176          50/102 Cuius errorem ex Pythagora et princip...
# 73   10484.txt    implicit       0.1163            7/41 Recte enim dictum est deum comprehens...
# 74   11372.txt    implicit       0.1154            9/20 Crede mihi, non est quies nisi in dom...
# 75   11751.txt    implicit       0.1143            5/34 deo, omnium bonorum authori
# 76   10067.txt    implicit       0.1111           79/31 Idcirco suam illam criminum propulsat...
# 77   11246.txt    implicit       0.1077           22/50 Non hoc tantum nomine, quod summo bon...
# 78   12805.txt    implicit       0.1053           22/20 N. Recipiunt hic sese tandem in portu...
# 79   12046.txt    implicit       0.1000          58/118 Quemadmodum d[ivus] Aurelius Augusti[...
# 80   11755.txt    implicit       0.0976            7/38 Errare possum, hereticus esse nolo.
# 81   11968.txt    implicit       0.0962           24/33 Quam sententiam caesar contra illum l...
# 82   11826.txt    implicit       0.0909           12/36 Ad quod respondemus exomologesim ritu...
# 83   11326.txt    implicit       0.0870           20/30 tertia die resuscitatum et in coelos ...
# 84   11990.txt    implicit       0.0833           30/22 Interea tamen, ut vere scribis, dissi...
# 85   12448.txt    implicit       0.0769           25/45 Cum Nazareis aut Mineis eundem Christ...
# 86   10484.txt    implicit       0.0741            6/52 Dei enim proprium est incomprehensibi...
# 87   13088.txt    implicit       0.0735           51/22 Absurdum plane dogma est, quod quidam...
# 88   12080.txt    implicit       0.0714           11/34 Veritas canonica aequat omnes per tot...
# 89   11171.txt    implicit       0.0667           28/20 Quemadmodum nanque deus per vos, fide...
# 90   11194.txt    implicit       0.0571           10/27 Speramus tamen illum favente domino n...
# 91   10511.txt    implicit       0.0526           10/50 unum oris et ventris, alterum animę e...
# 92   10511.txt    implicit       0.0294            3/32 celeste et terrestre
# 93   10768.txt    implicit       0.0280           72/75 Aber ich wais nichts witers darzuͦ uf...
# 94   13004.txt    implicit       0.0278           12/25 Wir muͤssen noch mitt dem hammer alle...
# 95   10908.txt    implicit       0.0234          19/112 Der münch ist wol gefuͤtert, feyst un...
# 96   10053.txt    implicit       0.0145           60/10 Dorumb das dises alles vermitten blib...
# 97   4178.txt     implicit       0.0000            5/20 Tolle spacia locorum corporibus etc.
